# %%
import sys
import os
import torch as T
import numpy as np
import random

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

# %%
def set_global_seed(seed: int):
    T.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)

    if T.cuda.is_available():
        T.cuda.manual_seed_all(seed)

# %%
SEED = 42

device = T.device('cuda' if T.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

set_global_seed(SEED)
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset Loading

# %%
from torch.utils.data import DataLoader
from datasets.custom_dataset import CustomWCSTDataset

# %% [markdown]
# ### 1. Dataset Hyperparameters

# %%
BATCH_SIZE = 64
TOTAL_BATCHES = 750
TRAIN_TEST_SPLIT_RATIO = 0.6
VALIDATION_TEST_SPLIT_RATIO = 0.5

N_5_features = {
    'colour': ['Red', 'Blue', 'Green', 'Yellow', 'Purple'],
    'shape': ['Circle', 'Square', 'Star', 'Cross', 'Triangle'],
    'quantity': ['One', 'Two', 'Three', 'Four', 'Five']
}


N_6_features = {
    'colour': ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange'],
    'shape': ['Circle', 'Square', 'Star', 'Cross', 'Triangle', 'Hexagon'],
    'quantity': ['One', 'Two', 'Three', 'Four', 'Five', 'Six']
}


N_7_features = {
    'colour': ['Red', 'Blue', 'Green', 'Yellow', 'Purple', 'Orange', 'Brown'],
    'shape': ['Circle', 'Square', 'Star', 'Cross', 'Triangle', 'Hexagon', 'Diamond'],
    'quantity': ['One', 'Two', 'Three', 'Four', 'Five', 'Six', 'Seven']
}

# %% [markdown]
# ### 2. Loading Dataset

# %%
train_size = int(TOTAL_BATCHES * TRAIN_TEST_SPLIT_RATIO)
validation_size = int((TOTAL_BATCHES - train_size) * VALIDATION_TEST_SPLIT_RATIO)
test_size = TOTAL_BATCHES - train_size - validation_size
                                                     
train_dataset = CustomWCSTDataset(total_batches=train_size, sample_batch_size=BATCH_SIZE, features=N_7_features)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_datasets = {
    "color": CustomWCSTDataset(
        total_batches=validation_size // 3, fixed_context=0, sample_batch_size=BATCH_SIZE, 
        allow_switch=False, features=N_7_features
        ),
    "shape": CustomWCSTDataset(
        total_batches=validation_size // 3, fixed_context=1, sample_batch_size=BATCH_SIZE, 
        allow_switch=False, features=N_7_features
        ),
    "quantity": CustomWCSTDataset(
        total_batches=validation_size // 3, fixed_context=2, sample_batch_size=BATCH_SIZE, 
        allow_switch=False, features=N_7_features
        )
}

validation_loaders = {
    ctx: DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True)
    for ctx, ds in validation_datasets.items()
}

test_dataset = CustomWCSTDataset(
        total_batches=test_size, sample_batch_size=BATCH_SIZE, features=N_7_features
    )
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Fixed context: 0
# [Dataset Init] Fixed context: 1
# [Dataset Init] Fixed context: 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1

# %% [markdown]
# ## Transformer Model Creation & Training

# %%
import numpy as np
from collections import defaultdict
from torch.utils.data import DataLoader
from torch import nn, optim

from src.transformer import CETransformer

# %% [markdown]
# ### 1. Train, Validate and Test Model Functions

# %%
def validate_per_context(
        model: nn.Module, criterion: nn.CrossEntropyLoss, loaders: dict[str, DataLoader], device: T.device | str ="cpu"
    ):
    model.eval()
    results = {}

    with T.no_grad():
        for ctx_name, loader in loaders.items():
            total_loss, total_correct, total_samples = 0.0, 0, 0
            for input_seq, target in loader:
                input_seq, target = input_seq.to(device), target.view(-1).to(device)

                logits = model(input_seq)
                logits = logits[:, -1, :]
                
                loss = criterion(logits, target)

                preds = logits.argmax(dim=1)
                total_loss += loss.item() * target.size(0)
                total_correct += (preds == target).sum().item()
                total_samples += target.size(0)

            avg_loss = total_loss / total_samples
            avg_acc = total_correct / total_samples

            results[ctx_name] = {
                "loss": avg_loss,
                "acc": avg_acc,
                "perplexity": np.exp(avg_loss)
            }
    return results

# %%
def train_model(
    train_loader: DataLoader, validation_loaders: dict[str, DataLoader], model: nn.Module, criterion: nn.CrossEntropyLoss, 
    optimizer: optim.Optimizer, max_epochs: int = 20, device: str | T.device = "cpu"
):
    history = defaultdict(list)

    for epoch in range(max_epochs):
        print(f"\nEpoch {epoch + 1}/{max_epochs}")
        print("-" * 40)

        # --- Training ---
        model.train()
        epoch_train_losses = []
        total_correct = 0
        total_samples = 0

        for batch_idx, (input_seq, target) in enumerate(train_loader):
            input_seq, target = input_seq.to(device), target.view(-1).to(device)

            # Forward pass
            logits = model(input_seq)  # [batch, seq_len, vocab]
            logits = logits[:, -1, :]  # only the final step prediction [batch, vocab]

            loss = criterion(logits, target)

            # Backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Accuracy
            preds = logits.argmax(dim=1)
            total_correct += (preds == target).sum().item()
            total_samples += target.size(0)

            epoch_train_losses.append(loss.item())

            if batch_idx % 100 == 0 or batch_idx == len(train_loader) - 1:
                print(f"Train Batch {batch_idx+1}/{len(train_loader)} | Loss: {loss.item():.4f}")

        train_loss = np.mean(epoch_train_losses)
        train_acc = total_correct / total_samples
        train_perplexity = np.exp(train_loss)

        history["train_losses"].append(train_loss)
        history["train_accs"].append(train_acc)
        history["train_perplexities"].append(train_perplexity)

        print(f"[Epoch {epoch+1}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Train Perplexity: {train_perplexity:.4f}")

        # --- Validation ---
        context_results = validate_per_context(model, criterion, validation_loaders, device)
        val_loss = []
        val_acc = []
        val_perplexity = []
        for ctx, metrics in context_results.items():
            print(f"[Validation] {ctx}: Loss={metrics['loss']:.4f} | Acc={metrics['acc']:.4f} | Perplexity={metrics['perplexity']:.4f}")
            val_loss.append(metrics['loss'])
            val_acc.append(metrics['acc'])
            val_perplexity.append(metrics['perplexity'])

        val_loss = np.mean(val_loss)
        val_acc = np.mean(val_acc)
        val_perplexity = np.mean(val_perplexity)

        print(f"[Validation Summary] Val Loss: {np.mean(val_loss):.4f} | "
              f"Val Acc: {np.mean(val_acc):.4f} | Val Perplexity: {np.mean(val_perplexity):.4f}", end="\n\n")
        print("-" * 40)

        history["val_context"].append(context_results)
        history["val_losses"].append(val_loss)
        history["val_accs"].append(val_acc)
        history["val_perplexities"].append(val_perplexity)

    print("\nTraining complete")

    return history

# %%
def test_model(test_loader: DataLoader, model: nn.Module, criterion: nn.CrossEntropyLoss, device: str | T.device = "cpu"):

    model.eval()
    test_batch_losses = []
    test_correct = 0
    test_tokens = 0

    with T.no_grad():
        for input_seq, target in test_loader:
            input_seq, target = input_seq.to(device), target.view(-1).to(device)

            # Forward pass
            logits = model(input_seq)  # [batch, seq_len, vocab]
            logits = logits[:, -1, :]
            loss = criterion(logits, target)

            preds = logits.argmax(dim=1)
            test_correct += (preds == target).sum().item()
            test_tokens += target.size(0)

            test_batch_losses.append(loss.item())

    test_loss = np.mean(test_batch_losses)
    test_acc = test_correct / test_tokens
    test_perplexity = np.exp(test_loss)

    return {
        "test_loss": test_loss,
        "test_acc": test_acc,
        "test_perplexity": test_perplexity
    }

# %% [markdown]
# ### 2. Create & Train Transformer Model

# %%
VOCABULARY_SIZE = train_dataset.vocabulary_size        # 64 cards + 4 categories + SEP + EOS
EMBEDDING_SIZE = 256        # larger embedding to capture card features
N_ATTENTION_HEADS = 8       # more heads for better multi-feature attention
N_BLOCKS = 6                # same depth as before
MAX_SEQUENCE_LENGTH = 13    # longer max sequence to accommodate multiple past trials
FF_DIMS = 1024               # larger feedforward layer for better representation
DROPOUT_PROB = 0.2        # reduce dropout slightly to retain signal in small batches
CARD_DIMS = (5, 5, 5)

LEARNING_RATE = 3e-4
BATCH_SIZE = 64
WEIGHT_DECAY = 1e-2
WARMUP_STEPS = 400
LABEL_SMOOTHING = 0.1
MAX_EPOCHS = 100
SEEDS = [31, 42, 45, 69, 420]

# %%
results = []
    
transformer = CETransformer(
    VOCABULARY_SIZE, CARD_DIMS, EMBEDDING_SIZE, N_ATTENTION_HEADS,
    N_BLOCKS, MAX_SEQUENCE_LENGTH, FF_DIMS, DROPOUT_PROB, device=device
)

criterion =  nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTHING)
optimizer = optim.AdamW(transformer.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=WARMUP_STEPS)  

result = train_model(
    train_loader, validation_loaders, transformer, criterion,
    optimizer, max_epochs=MAX_EPOCHS, device=device
)

test_results = test_model(test_loader, transformer, criterion, device)
print(f"[Test] Loss: {test_results["test_loss"]:.4f} | Acc: {test_results["test_acc"]:.4f} | Perplexity: {test_results["test_perplexity"]:.4f}")

results.append({**result, **test_results})
# Out:
# Epoch 1/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 153.6825
# Train Batch 101/450 | Loss: 6.2566
# Train Batch 201/450 | Loss: 4.8835
# Train Batch 301/450 | Loss: 4.8185
# Train Batch 401/450 | Loss: 4.4816
# Train Batch 450/450 | Loss: 3.9415
# [Epoch 1] Train Loss: 6.2888 | Train Acc: 0.1362 | Train Perplexity: 538.5137
# [Validation] color: Loss=3.2958 | Acc=0.1397 | Perplexity=26.9978
# [Validation] shape: Loss=3.2845 | Acc=0.1441 | Perplexity=26.6968
# [Validation] quantity: Loss=3.2751 | Acc=0.1459 | Perplexity=26.4450
# [Validation Summary] Val Loss: 3.2851 | Val Acc: 0.1432 | Val Perplexity: 26.7132
#
# ----------------------------------------
#
# Epoch 2/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 4.0094
# Train Batch 101/450 | Loss: 4.1517
# Train Batch 201/450 | Loss: 3.9081
# Train Batch 301/450 | Loss: 3.9609
# Train Batch 401/450 | Loss: 3.6431
# Train Batch 450/450 | Loss: 3.3915
# [Epoch 2] Train Loss: 3.7663 | Train Acc: 0.1447 | Train Perplexity: 43.2194
# [Validation] color: Loss=2.9119 | Acc=0.1403 | Perplexity=18.3924
# [Validation] shape: Loss=2.9000 | Acc=0.1519 | Perplexity=18.1745
# [Validation] quantity: Loss=2.9145 | Acc=0.1522 | Perplexity=18.4387
# [Validation Summary] Val Loss: 2.9088 | Val Acc: 0.1481 | Val Perplexity: 18.3352
#
# ----------------------------------------
#
# Epoch 3/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 3.2604
# Train Batch 101/450 | Loss: 3.4383
# Train Batch 201/450 | Loss: 3.6210
# Train Batch 301/450 | Loss: 3.2034
# Train Batch 401/450 | Loss: 3.2821
# Train Batch 450/450 | Loss: 3.4189
# [Epoch 3] Train Loss: 3.3936 | Train Acc: 0.1453 | Train Perplexity: 29.7730
# [Validation] color: Loss=2.9623 | Acc=0.1403 | Perplexity=19.3415
# [Validation] shape: Loss=2.9620 | Acc=0.1519 | Perplexity=19.3376
# [Validation] quantity: Loss=2.9569 | Acc=0.1522 | Perplexity=19.2379
# [Validation Summary] Val Loss: 2.9604 | Val Acc: 0.1481 | Val Perplexity: 19.3056
#
# ----------------------------------------
#
# Epoch 4/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 3.4874
# Train Batch 101/450 | Loss: 3.1166
# Train Batch 201/450 | Loss: 3.4444
# Train Batch 301/450 | Loss: 3.3684
# Train Batch 401/450 | Loss: 3.1995
# Train Batch 450/450 | Loss: 3.3068
# [Epoch 4] Train Loss: 3.1896 | Train Acc: 0.1434 | Train Perplexity: 24.2799
# [Validation] color: Loss=2.8322 | Acc=0.1478 | Perplexity=16.9831
# [Validation] shape: Loss=2.8369 | Acc=0.1503 | Perplexity=17.0633
# [Validation] quantity: Loss=2.8370 | Acc=0.1328 | Perplexity=17.0653
# [Validation Summary] Val Loss: 2.8354 | Val Acc: 0.1436 | Val Perplexity: 17.0372
#
# ----------------------------------------
#
# Epoch 5/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 3.1343
# Train Batch 101/450 | Loss: 3.2472
# Train Batch 201/450 | Loss: 3.4367
# Train Batch 301/450 | Loss: 3.0535
# Train Batch 401/450 | Loss: 3.0370
# Train Batch 450/450 | Loss: 2.9954
# [Epoch 5] Train Loss: 3.0817 | Train Acc: 0.1452 | Train Perplexity: 21.7963
# [Validation] color: Loss=2.8507 | Acc=0.1397 | Perplexity=17.2992
# [Validation] shape: Loss=2.8527 | Acc=0.1516 | Perplexity=17.3345
# [Validation] quantity: Loss=2.8549 | Acc=0.1484 | Perplexity=17.3719
# [Validation Summary] Val Loss: 2.8527 | Val Acc: 0.1466 | Val Perplexity: 17.3352
#
# ----------------------------------------
#
# Epoch 6/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 3.1096
# Train Batch 101/450 | Loss: 2.9259
# Train Batch 201/450 | Loss: 2.8413
# Train Batch 301/450 | Loss: 2.9859
# Train Batch 401/450 | Loss: 2.8917
# Train Batch 450/450 | Loss: 3.3169
# [Epoch 6] Train Loss: 3.0122 | Train Acc: 0.1433 | Train Perplexity: 20.3313
# [Validation] color: Loss=2.7515 | Acc=0.1419 | Perplexity=15.6665
# [Validation] shape: Loss=2.7467 | Acc=0.1544 | Perplexity=15.5912
# [Validation] quantity: Loss=2.7385 | Acc=0.1437 | Perplexity=15.4640
# [Validation Summary] Val Loss: 2.7456 | Val Acc: 0.1467 | Val Perplexity: 15.5739
#
# ----------------------------------------
#
# Epoch 7/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.8103
# Train Batch 101/450 | Loss: 2.8723
# Train Batch 201/450 | Loss: 3.0877
# Train Batch 301/450 | Loss: 2.8842
# Train Batch 401/450 | Loss: 2.9260
# Train Batch 450/450 | Loss: 3.0033
# [Epoch 7] Train Loss: 2.9473 | Train Acc: 0.1453 | Train Perplexity: 19.0546
# [Validation] color: Loss=2.7393 | Acc=0.1459 | Perplexity=15.4761
# [Validation] shape: Loss=2.7438 | Acc=0.1441 | Perplexity=15.5459
# [Validation] quantity: Loss=2.7412 | Acc=0.1350 | Perplexity=15.5058
# [Validation Summary] Val Loss: 2.7414 | Val Acc: 0.1417 | Val Perplexity: 15.5093
#
# ----------------------------------------
#
# Epoch 8/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.8446
# Train Batch 101/450 | Loss: 2.9627
# Train Batch 201/450 | Loss: 2.9129
# Train Batch 301/450 | Loss: 2.8663
# Train Batch 401/450 | Loss: 2.7941
# Train Batch 450/450 | Loss: 2.9923
# [Epoch 8] Train Loss: 2.9006 | Train Acc: 0.1462 | Train Perplexity: 18.1853
# [Validation] color: Loss=2.7520 | Acc=0.1403 | Perplexity=15.6736
# [Validation] shape: Loss=2.7503 | Acc=0.1569 | Perplexity=15.6480
# [Validation] quantity: Loss=2.7447 | Acc=0.1494 | Perplexity=15.5606
# [Validation Summary] Val Loss: 2.7490 | Val Acc: 0.1489 | Val Perplexity: 15.6274
#
# ----------------------------------------
#
# Epoch 9/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.9267
# Train Batch 101/450 | Loss: 2.9377
# Train Batch 201/450 | Loss: 2.9299
# Train Batch 301/450 | Loss: 2.8845
# Train Batch 401/450 | Loss: 2.7778
# Train Batch 450/450 | Loss: 2.7217
# [Epoch 9] Train Loss: 2.8661 | Train Acc: 0.1514 | Train Perplexity: 17.5692
# [Validation] color: Loss=2.7378 | Acc=0.1428 | Perplexity=15.4523
# [Validation] shape: Loss=2.7446 | Acc=0.1459 | Perplexity=15.5589
# [Validation] quantity: Loss=2.7420 | Acc=0.1487 | Perplexity=15.5177
# [Validation Summary] Val Loss: 2.7415 | Val Acc: 0.1458 | Val Perplexity: 15.5097
#
# ----------------------------------------
#
# Epoch 10/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.7840
# Train Batch 101/450 | Loss: 2.8112
# Train Batch 201/450 | Loss: 2.7619
# Train Batch 301/450 | Loss: 2.9026
# Train Batch 401/450 | Loss: 2.8147
# Train Batch 450/450 | Loss: 2.7460
# [Epoch 10] Train Loss: 2.8241 | Train Acc: 0.1533 | Train Perplexity: 16.8452
# [Validation] color: Loss=2.7927 | Acc=0.1550 | Perplexity=16.3246
# [Validation] shape: Loss=2.7865 | Acc=0.1441 | Perplexity=16.2233
# [Validation] quantity: Loss=2.8086 | Acc=0.1359 | Perplexity=16.5869
# [Validation Summary] Val Loss: 2.7959 | Val Acc: 0.1450 | Val Perplexity: 16.3783
#
# ----------------------------------------
#
# Epoch 11/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.8850
# Train Batch 101/450 | Loss: 2.8357
# Train Batch 201/450 | Loss: 2.7464
# Train Batch 301/450 | Loss: 2.8292
# Train Batch 401/450 | Loss: 2.7784
# Train Batch 450/450 | Loss: 2.7658
# [Epoch 11] Train Loss: 2.7918 | Train Acc: 0.1599 | Train Perplexity: 16.3103
# [Validation] color: Loss=2.7782 | Acc=0.1462 | Perplexity=16.0905
# [Validation] shape: Loss=2.7683 | Acc=0.1472 | Perplexity=15.9322
# [Validation] quantity: Loss=2.7832 | Acc=0.1437 | Perplexity=16.1711
# [Validation Summary] Val Loss: 2.7766 | Val Acc: 0.1457 | Val Perplexity: 16.0646
#
# ----------------------------------------
#
# Epoch 12/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.9079
# Train Batch 101/450 | Loss: 2.8727
# Train Batch 201/450 | Loss: 2.7590
# Train Batch 301/450 | Loss: 2.7504
# Train Batch 401/450 | Loss: 2.7098
# Train Batch 450/450 | Loss: 2.8437
# [Epoch 12] Train Loss: 2.7773 | Train Acc: 0.1621 | Train Perplexity: 16.0761
# [Validation] color: Loss=2.7904 | Acc=0.1391 | Perplexity=16.2868
# [Validation] shape: Loss=2.7914 | Acc=0.1472 | Perplexity=16.3038
# [Validation] quantity: Loss=2.7836 | Acc=0.1313 | Perplexity=16.1778
# [Validation Summary] Val Loss: 2.7885 | Val Acc: 0.1392 | Val Perplexity: 16.2561
#
# ----------------------------------------
#
# Epoch 13/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.8787
# Train Batch 101/450 | Loss: 2.7587
# Train Batch 201/450 | Loss: 2.7437
# Train Batch 301/450 | Loss: 2.6722
# Train Batch 401/450 | Loss: 2.7307
# Train Batch 450/450 | Loss: 2.7590
# [Epoch 13] Train Loss: 2.7489 | Train Acc: 0.1653 | Train Perplexity: 15.6258
# [Validation] color: Loss=2.7525 | Acc=0.1403 | Perplexity=15.6821
# [Validation] shape: Loss=2.7539 | Acc=0.1434 | Perplexity=15.7037
# [Validation] quantity: Loss=2.7456 | Acc=0.1462 | Perplexity=15.5745
# [Validation Summary] Val Loss: 2.7507 | Val Acc: 0.1433 | Val Perplexity: 15.6534
#
# ----------------------------------------
#
# Epoch 14/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.7735
# Train Batch 101/450 | Loss: 2.6846
# Train Batch 201/450 | Loss: 2.7637
# Train Batch 301/450 | Loss: 2.6988
# Train Batch 401/450 | Loss: 2.6847
# Train Batch 450/450 | Loss: 2.7013
# [Epoch 14] Train Loss: 2.7275 | Train Acc: 0.1725 | Train Perplexity: 15.2949
# [Validation] color: Loss=2.7263 | Acc=0.1400 | Perplexity=15.2764
# [Validation] shape: Loss=2.7192 | Acc=0.1534 | Perplexity=15.1688
# [Validation] quantity: Loss=2.7179 | Acc=0.1363 | Perplexity=15.1484
# [Validation Summary] Val Loss: 2.7211 | Val Acc: 0.1432 | Val Perplexity: 15.1979
#
# ----------------------------------------
#
# Epoch 15/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6763
# Train Batch 101/450 | Loss: 2.6449
# Train Batch 201/450 | Loss: 2.6443
# Train Batch 301/450 | Loss: 2.7053
# Train Batch 401/450 | Loss: 2.7171
# Train Batch 450/450 | Loss: 2.7063
# [Epoch 15] Train Loss: 2.7107 | Train Acc: 0.1779 | Train Perplexity: 15.0403
# [Validation] color: Loss=2.7214 | Acc=0.1322 | Perplexity=15.2021
# [Validation] shape: Loss=2.7218 | Acc=0.1437 | Perplexity=15.2080
# [Validation] quantity: Loss=2.7171 | Acc=0.1525 | Perplexity=15.1358
# [Validation Summary] Val Loss: 2.7201 | Val Acc: 0.1428 | Val Perplexity: 15.1820
#
# ----------------------------------------
#
# Epoch 16/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6752
# Train Batch 101/450 | Loss: 2.7469
# Train Batch 201/450 | Loss: 2.7346
# Train Batch 301/450 | Loss: 2.8147
# Train Batch 401/450 | Loss: 2.5676
# Train Batch 450/450 | Loss: 2.6396
# [Epoch 16] Train Loss: 2.6921 | Train Acc: 0.1878 | Train Perplexity: 14.7626
# [Validation] color: Loss=2.7397 | Acc=0.1369 | Perplexity=15.4820
# [Validation] shape: Loss=2.7284 | Acc=0.1491 | Perplexity=15.3089
# [Validation] quantity: Loss=2.7300 | Acc=0.1437 | Perplexity=15.3335
# [Validation Summary] Val Loss: 2.7327 | Val Acc: 0.1432 | Val Perplexity: 15.3748
#
# ----------------------------------------
#
# Epoch 17/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.7038
# Train Batch 101/450 | Loss: 2.6658
# Train Batch 201/450 | Loss: 2.6387
# Train Batch 301/450 | Loss: 2.7261
# Train Batch 401/450 | Loss: 2.6955
# Train Batch 450/450 | Loss: 2.6436
# [Epoch 17] Train Loss: 2.6747 | Train Acc: 0.1931 | Train Perplexity: 14.5074
# [Validation] color: Loss=2.7256 | Acc=0.1391 | Perplexity=15.2649
# [Validation] shape: Loss=2.7137 | Acc=0.1509 | Perplexity=15.0851
# [Validation] quantity: Loss=2.7149 | Acc=0.1466 | Perplexity=15.1033
# [Validation Summary] Val Loss: 2.7181 | Val Acc: 0.1455 | Val Perplexity: 15.1511
#
# ----------------------------------------
#
# Epoch 18/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6794
# Train Batch 101/450 | Loss: 2.7229
# Train Batch 201/450 | Loss: 2.6676
# Train Batch 301/450 | Loss: 2.6265
# Train Batch 401/450 | Loss: 2.6441
# Train Batch 450/450 | Loss: 2.6393
# [Epoch 18] Train Loss: 2.6689 | Train Acc: 0.2001 | Train Perplexity: 14.4239
# [Validation] color: Loss=2.7198 | Acc=0.1422 | Perplexity=15.1774
# [Validation] shape: Loss=2.7111 | Acc=0.1503 | Perplexity=15.0458
# [Validation] quantity: Loss=2.7017 | Acc=0.1553 | Perplexity=14.9057
# [Validation Summary] Val Loss: 2.7109 | Val Acc: 0.1493 | Val Perplexity: 15.0430
#
# ----------------------------------------
#
# Epoch 19/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6952
# Train Batch 101/450 | Loss: 2.7343
# Train Batch 201/450 | Loss: 2.6153
# Train Batch 301/450 | Loss: 2.6746
# Train Batch 401/450 | Loss: 2.6512
# Train Batch 450/450 | Loss: 2.7193
# [Epoch 19] Train Loss: 2.6554 | Train Acc: 0.2082 | Train Perplexity: 14.2302
# [Validation] color: Loss=2.7609 | Acc=0.1444 | Perplexity=15.8146
# [Validation] shape: Loss=2.7743 | Acc=0.1356 | Perplexity=16.0274
# [Validation] quantity: Loss=2.7544 | Acc=0.1541 | Perplexity=15.7108
# [Validation Summary] Val Loss: 2.7632 | Val Acc: 0.1447 | Val Perplexity: 15.8509
#
# ----------------------------------------
#
# Epoch 20/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5997
# Train Batch 101/450 | Loss: 2.6142
# Train Batch 201/450 | Loss: 2.7805
# Train Batch 301/450 | Loss: 2.6482
# Train Batch 401/450 | Loss: 2.6858
# Train Batch 450/450 | Loss: 2.6273
# [Epoch 20] Train Loss: 2.6513 | Train Acc: 0.2073 | Train Perplexity: 14.1729
# [Validation] color: Loss=2.7473 | Acc=0.1316 | Perplexity=15.5998
# [Validation] shape: Loss=2.7303 | Acc=0.1459 | Perplexity=15.3380
# [Validation] quantity: Loss=2.7297 | Acc=0.1400 | Perplexity=15.3287
# [Validation Summary] Val Loss: 2.7358 | Val Acc: 0.1392 | Val Perplexity: 15.4222
#
# ----------------------------------------
#
# Epoch 21/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6839
# Train Batch 101/450 | Loss: 2.6350
# Train Batch 201/450 | Loss: 2.6341
# Train Batch 301/450 | Loss: 2.7533
# Train Batch 401/450 | Loss: 2.6056
# Train Batch 450/450 | Loss: 2.6564
# [Epoch 21] Train Loss: 2.6315 | Train Acc: 0.2157 | Train Perplexity: 13.8952
# [Validation] color: Loss=2.7755 | Acc=0.1331 | Perplexity=16.0460
# [Validation] shape: Loss=2.7570 | Acc=0.1419 | Perplexity=15.7524
# [Validation] quantity: Loss=2.7600 | Acc=0.1456 | Perplexity=15.8000
# [Validation Summary] Val Loss: 2.7642 | Val Acc: 0.1402 | Val Perplexity: 15.8661
#
# ----------------------------------------
#
# Epoch 22/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6321
# Train Batch 101/450 | Loss: 2.7230
# Train Batch 201/450 | Loss: 2.6069
# Train Batch 301/450 | Loss: 2.5546
# Train Batch 401/450 | Loss: 2.6034
# Train Batch 450/450 | Loss: 2.5749
# [Epoch 22] Train Loss: 2.6329 | Train Acc: 0.2189 | Train Perplexity: 13.9140
# [Validation] color: Loss=2.7594 | Acc=0.1363 | Perplexity=15.7904
# [Validation] shape: Loss=2.7566 | Acc=0.1459 | Perplexity=15.7457
# [Validation] quantity: Loss=2.7585 | Acc=0.1381 | Perplexity=15.7762
# [Validation Summary] Val Loss: 2.7582 | Val Acc: 0.1401 | Val Perplexity: 15.7708
#
# ----------------------------------------
#
# Epoch 23/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5687
# Train Batch 101/450 | Loss: 2.5503
# Train Batch 201/450 | Loss: 2.6515
# Train Batch 301/450 | Loss: 2.6405
# Train Batch 401/450 | Loss: 2.6193
# Train Batch 450/450 | Loss: 2.6618
# [Epoch 23] Train Loss: 2.6427 | Train Acc: 0.2153 | Train Perplexity: 14.0514
# [Validation] color: Loss=2.7310 | Acc=0.1322 | Perplexity=15.3481
# [Validation] shape: Loss=2.7301 | Acc=0.1384 | Perplexity=15.3351
# [Validation] quantity: Loss=2.7142 | Acc=0.1462 | Perplexity=15.0925
# [Validation Summary] Val Loss: 2.7251 | Val Acc: 0.1390 | Val Perplexity: 15.2586
#
# ----------------------------------------
#
# Epoch 24/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6136
# Train Batch 101/450 | Loss: 2.6685
# Train Batch 201/450 | Loss: 2.6818
# Train Batch 301/450 | Loss: 2.5720
# Train Batch 401/450 | Loss: 2.5440
# Train Batch 450/450 | Loss: 2.5998
# [Epoch 24] Train Loss: 2.6248 | Train Acc: 0.2205 | Train Perplexity: 13.8011
# [Validation] color: Loss=2.7538 | Acc=0.1225 | Perplexity=15.7024
# [Validation] shape: Loss=2.7495 | Acc=0.1481 | Perplexity=15.6341
# [Validation] quantity: Loss=2.7436 | Acc=0.1369 | Perplexity=15.5428
# [Validation Summary] Val Loss: 2.7490 | Val Acc: 0.1358 | Val Perplexity: 15.6264
#
# ----------------------------------------
#
# Epoch 25/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5964
# Train Batch 101/450 | Loss: 2.5387
# Train Batch 201/450 | Loss: 2.6123
# Train Batch 301/450 | Loss: 2.5234
# Train Batch 401/450 | Loss: 2.6993
# Train Batch 450/450 | Loss: 2.5471
# [Epoch 25] Train Loss: 2.6048 | Train Acc: 0.2353 | Train Perplexity: 13.5279
# [Validation] color: Loss=2.8500 | Acc=0.1297 | Perplexity=17.2871
# [Validation] shape: Loss=2.8379 | Acc=0.1478 | Perplexity=17.0792
# [Validation] quantity: Loss=2.8507 | Acc=0.1447 | Perplexity=17.2999
# [Validation Summary] Val Loss: 2.8462 | Val Acc: 0.1407 | Val Perplexity: 17.2221
#
# ----------------------------------------
#
# Epoch 26/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6081
# Train Batch 101/450 | Loss: 2.5564
# Train Batch 201/450 | Loss: 2.5405
# Train Batch 301/450 | Loss: 2.6102
# Train Batch 401/450 | Loss: 2.5761
# Train Batch 450/450 | Loss: 2.5322
# [Epoch 26] Train Loss: 2.5969 | Train Acc: 0.2385 | Train Perplexity: 13.4217
# [Validation] color: Loss=2.7850 | Acc=0.1462 | Perplexity=16.2001
# [Validation] shape: Loss=2.7843 | Acc=0.1459 | Perplexity=16.1884
# [Validation] quantity: Loss=2.7708 | Acc=0.1494 | Perplexity=15.9719
# [Validation Summary] Val Loss: 2.7800 | Val Acc: 0.1472 | Val Perplexity: 16.1201
#
# ----------------------------------------
#
# Epoch 27/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6449
# Train Batch 101/450 | Loss: 2.6400
# Train Batch 201/450 | Loss: 2.4877
# Train Batch 301/450 | Loss: 2.5562
# Train Batch 401/450 | Loss: 2.5116
# Train Batch 450/450 | Loss: 2.5052
# [Epoch 27] Train Loss: 2.5854 | Train Acc: 0.2497 | Train Perplexity: 13.2688
# [Validation] color: Loss=2.8116 | Acc=0.1322 | Perplexity=16.6365
# [Validation] shape: Loss=2.8069 | Acc=0.1459 | Perplexity=16.5589
# [Validation] quantity: Loss=2.8087 | Acc=0.1366 | Perplexity=16.5891
# [Validation Summary] Val Loss: 2.8091 | Val Acc: 0.1382 | Val Perplexity: 16.5948
#
# ----------------------------------------
#
# Epoch 28/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5352
# Train Batch 101/450 | Loss: 2.6111
# Train Batch 201/450 | Loss: 2.6038
# Train Batch 301/450 | Loss: 2.5511
# Train Batch 401/450 | Loss: 2.5212
# Train Batch 450/450 | Loss: 2.6309
# [Epoch 28] Train Loss: 2.5782 | Train Acc: 0.2536 | Train Perplexity: 13.1731
# [Validation] color: Loss=2.7790 | Acc=0.1381 | Perplexity=16.1029
# [Validation] shape: Loss=2.7702 | Acc=0.1494 | Perplexity=15.9619
# [Validation] quantity: Loss=2.7574 | Acc=0.1525 | Perplexity=15.7589
# [Validation Summary] Val Loss: 2.7689 | Val Acc: 0.1467 | Val Perplexity: 15.9412
#
# ----------------------------------------
#
# Epoch 29/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4554
# Train Batch 101/450 | Loss: 2.4339
# Train Batch 201/450 | Loss: 2.5984
# Train Batch 301/450 | Loss: 2.4745
# Train Batch 401/450 | Loss: 2.5586
# Train Batch 450/450 | Loss: 2.6091
# [Epoch 29] Train Loss: 2.5697 | Train Acc: 0.2619 | Train Perplexity: 13.0619
# [Validation] color: Loss=2.7869 | Acc=0.1322 | Perplexity=16.2311
# [Validation] shape: Loss=2.7829 | Acc=0.1537 | Perplexity=16.1656
# [Validation] quantity: Loss=2.7738 | Acc=0.1459 | Perplexity=16.0188
# [Validation Summary] Val Loss: 2.7812 | Val Acc: 0.1440 | Val Perplexity: 16.1385
#
# ----------------------------------------
#
# Epoch 30/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5865
# Train Batch 101/450 | Loss: 2.6170
# Train Batch 201/450 | Loss: 2.5708
# Train Batch 301/450 | Loss: 2.5244
# Train Batch 401/450 | Loss: 2.5101
# Train Batch 450/450 | Loss: 2.6037
# [Epoch 30] Train Loss: 2.5532 | Train Acc: 0.2667 | Train Perplexity: 12.8484
# [Validation] color: Loss=2.8161 | Acc=0.1359 | Perplexity=16.7108
# [Validation] shape: Loss=2.8073 | Acc=0.1597 | Perplexity=16.5659
# [Validation] quantity: Loss=2.8025 | Acc=0.1547 | Perplexity=16.4853
# [Validation Summary] Val Loss: 2.8086 | Val Acc: 0.1501 | Val Perplexity: 16.5873
#
# ----------------------------------------
#
# Epoch 31/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4217
# Train Batch 101/450 | Loss: 2.5673
# Train Batch 201/450 | Loss: 2.6236
# Train Batch 301/450 | Loss: 2.5604
# Train Batch 401/450 | Loss: 2.5509
# Train Batch 450/450 | Loss: 2.5716
# [Epoch 31] Train Loss: 2.5473 | Train Acc: 0.2746 | Train Perplexity: 12.7723
# [Validation] color: Loss=2.7957 | Acc=0.1403 | Perplexity=16.3744
# [Validation] shape: Loss=2.7933 | Acc=0.1506 | Perplexity=16.3354
# [Validation] quantity: Loss=2.7856 | Acc=0.1459 | Perplexity=16.2097
# [Validation Summary] Val Loss: 2.7916 | Val Acc: 0.1456 | Val Perplexity: 16.3065
#
# ----------------------------------------
#
# Epoch 32/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5391
# Train Batch 101/450 | Loss: 2.4411
# Train Batch 201/450 | Loss: 2.5499
# Train Batch 301/450 | Loss: 2.5491
# Train Batch 401/450 | Loss: 2.6493
# Train Batch 450/450 | Loss: 2.5199
# [Epoch 32] Train Loss: 2.5301 | Train Acc: 0.2871 | Train Perplexity: 12.5543
# [Validation] color: Loss=2.8354 | Acc=0.1388 | Perplexity=17.0370
# [Validation] shape: Loss=2.8392 | Acc=0.1516 | Perplexity=17.1022
# [Validation] quantity: Loss=2.8354 | Acc=0.1462 | Perplexity=17.0366
# [Validation Summary] Val Loss: 2.8367 | Val Acc: 0.1455 | Val Perplexity: 17.0586
#
# ----------------------------------------
#
# Epoch 33/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6348
# Train Batch 101/450 | Loss: 2.4591
# Train Batch 201/450 | Loss: 2.5370
# Train Batch 301/450 | Loss: 2.5415
# Train Batch 401/450 | Loss: 2.5157
# Train Batch 450/450 | Loss: 2.4878
# [Epoch 33] Train Loss: 2.5426 | Train Acc: 0.2777 | Train Perplexity: 12.7126
# [Validation] color: Loss=2.7754 | Acc=0.1447 | Perplexity=16.0447
# [Validation] shape: Loss=2.7935 | Acc=0.1375 | Perplexity=16.3384
# [Validation] quantity: Loss=2.7792 | Acc=0.1444 | Perplexity=16.1069
# [Validation Summary] Val Loss: 2.7827 | Val Acc: 0.1422 | Val Perplexity: 16.1633
#
# ----------------------------------------
#
# Epoch 34/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5405
# Train Batch 101/450 | Loss: 2.6180
# Train Batch 201/450 | Loss: 2.5129
# Train Batch 301/450 | Loss: 2.6282
# Train Batch 401/450 | Loss: 2.5587
# Train Batch 450/450 | Loss: 2.6280
# [Epoch 34] Train Loss: 2.5640 | Train Acc: 0.2625 | Train Perplexity: 12.9879
# [Validation] color: Loss=2.7778 | Acc=0.1381 | Perplexity=16.0831
# [Validation] shape: Loss=2.7727 | Acc=0.1541 | Perplexity=16.0025
# [Validation] quantity: Loss=2.7717 | Acc=0.1491 | Perplexity=15.9854
# [Validation Summary] Val Loss: 2.7741 | Val Acc: 0.1471 | Val Perplexity: 16.0237
#
# ----------------------------------------
#
# Epoch 35/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.6572
# Train Batch 101/450 | Loss: 2.5374
# Train Batch 201/450 | Loss: 2.5037
# Train Batch 301/450 | Loss: 2.5338
# Train Batch 401/450 | Loss: 2.5290
# Train Batch 450/450 | Loss: 2.4506
# [Epoch 35] Train Loss: 2.5590 | Train Acc: 0.2618 | Train Perplexity: 12.9226
# [Validation] color: Loss=2.8112 | Acc=0.1503 | Perplexity=16.6299
# [Validation] shape: Loss=2.8116 | Acc=0.1491 | Perplexity=16.6361
# [Validation] quantity: Loss=2.8075 | Acc=0.1491 | Perplexity=16.5683
# [Validation Summary] Val Loss: 2.8101 | Val Acc: 0.1495 | Val Perplexity: 16.6114
#
# ----------------------------------------
#
# Epoch 36/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4633
# Train Batch 101/450 | Loss: 2.5059
# Train Batch 201/450 | Loss: 2.4865
# Train Batch 301/450 | Loss: 2.5057
# Train Batch 401/450 | Loss: 2.5400
# Train Batch 450/450 | Loss: 2.5763
# [Epoch 36] Train Loss: 2.5285 | Train Acc: 0.2847 | Train Perplexity: 12.5347
# [Validation] color: Loss=2.8444 | Acc=0.1363 | Perplexity=17.1912
# [Validation] shape: Loss=2.8302 | Acc=0.1487 | Perplexity=16.9497
# [Validation] quantity: Loss=2.8263 | Acc=0.1437 | Perplexity=16.8827
# [Validation Summary] Val Loss: 2.8336 | Val Acc: 0.1429 | Val Perplexity: 17.0079
#
# ----------------------------------------
#
# Epoch 37/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5816
# Train Batch 101/450 | Loss: 2.5818
# Train Batch 201/450 | Loss: 2.4809
# Train Batch 301/450 | Loss: 2.6287
# Train Batch 401/450 | Loss: 2.6349
# Train Batch 450/450 | Loss: 2.4654
# [Epoch 37] Train Loss: 2.5081 | Train Acc: 0.2982 | Train Perplexity: 12.2813
# [Validation] color: Loss=2.8604 | Acc=0.1369 | Perplexity=17.4678
# [Validation] shape: Loss=2.8565 | Acc=0.1528 | Perplexity=17.4008
# [Validation] quantity: Loss=2.8521 | Acc=0.1416 | Perplexity=17.3242
# [Validation Summary] Val Loss: 2.8563 | Val Acc: 0.1438 | Val Perplexity: 17.3976
#
# ----------------------------------------
#
# Epoch 38/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4462
# Train Batch 101/450 | Loss: 2.4255
# Train Batch 201/450 | Loss: 2.4005
# Train Batch 301/450 | Loss: 2.4313
# Train Batch 401/450 | Loss: 2.5249
# Train Batch 450/450 | Loss: 2.4427
# [Epoch 38] Train Loss: 2.4913 | Train Acc: 0.3072 | Train Perplexity: 12.0764
# [Validation] color: Loss=2.8878 | Acc=0.1406 | Perplexity=17.9544
# [Validation] shape: Loss=2.8812 | Acc=0.1531 | Perplexity=17.8350
# [Validation] quantity: Loss=2.8812 | Acc=0.1462 | Perplexity=17.8357
# [Validation Summary] Val Loss: 2.8834 | Val Acc: 0.1467 | Val Perplexity: 17.8751
#
# ----------------------------------------
#
# Epoch 39/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.5630
# Train Batch 101/450 | Loss: 2.3315
# Train Batch 201/450 | Loss: 2.4511
# Train Batch 301/450 | Loss: 2.3327
# Train Batch 401/450 | Loss: 2.5953
# Train Batch 450/450 | Loss: 2.5050
# [Epoch 39] Train Loss: 2.4745 | Train Acc: 0.3208 | Train Perplexity: 11.8759
# [Validation] color: Loss=2.9010 | Acc=0.1475 | Perplexity=18.1930
# [Validation] shape: Loss=2.9054 | Acc=0.1553 | Perplexity=18.2719
# [Validation] quantity: Loss=2.8935 | Acc=0.1547 | Perplexity=18.0560
# [Validation Summary] Val Loss: 2.9000 | Val Acc: 0.1525 | Val Perplexity: 18.1736
#
# ----------------------------------------
#
# Epoch 40/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4791
# Train Batch 101/450 | Loss: 2.3998
# Train Batch 201/450 | Loss: 2.4726
# Train Batch 301/450 | Loss: 2.3073
# Train Batch 401/450 | Loss: 2.4057
# Train Batch 450/450 | Loss: 2.3780
# [Epoch 40] Train Loss: 2.4577 | Train Acc: 0.3311 | Train Perplexity: 11.6779
# [Validation] color: Loss=2.9159 | Acc=0.1412 | Perplexity=18.4663
# [Validation] shape: Loss=2.9251 | Acc=0.1547 | Perplexity=18.6359
# [Validation] quantity: Loss=2.9009 | Acc=0.1531 | Perplexity=18.1907
# [Validation Summary] Val Loss: 2.9140 | Val Acc: 0.1497 | Val Perplexity: 18.4310
#
# ----------------------------------------
#
# Epoch 41/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3917
# Train Batch 101/450 | Loss: 2.4374
# Train Batch 201/450 | Loss: 2.4515
# Train Batch 301/450 | Loss: 2.3878
# Train Batch 401/450 | Loss: 2.5029
# Train Batch 450/450 | Loss: 2.5509
# [Epoch 41] Train Loss: 2.4387 | Train Acc: 0.3403 | Train Perplexity: 11.4582
# [Validation] color: Loss=2.9399 | Acc=0.1344 | Perplexity=18.9148
# [Validation] shape: Loss=2.9513 | Acc=0.1481 | Perplexity=19.1302
# [Validation] quantity: Loss=2.9302 | Acc=0.1487 | Perplexity=18.7314
# [Validation Summary] Val Loss: 2.9405 | Val Acc: 0.1437 | Val Perplexity: 18.9254
#
# ----------------------------------------
#
# Epoch 42/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2664
# Train Batch 101/450 | Loss: 2.4118
# Train Batch 201/450 | Loss: 2.4537
# Train Batch 301/450 | Loss: 2.3795
# Train Batch 401/450 | Loss: 2.5311
# Train Batch 450/450 | Loss: 2.3746
# [Epoch 42] Train Loss: 2.4214 | Train Acc: 0.3469 | Train Perplexity: 11.2612
# [Validation] color: Loss=2.9421 | Acc=0.1412 | Perplexity=18.9564
# [Validation] shape: Loss=2.9509 | Acc=0.1487 | Perplexity=19.1222
# [Validation] quantity: Loss=2.9236 | Acc=0.1531 | Perplexity=18.6077
# [Validation Summary] Val Loss: 2.9389 | Val Acc: 0.1477 | Val Perplexity: 18.8954
#
# ----------------------------------------
#
# Epoch 43/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2711
# Train Batch 101/450 | Loss: 2.3414
# Train Batch 201/450 | Loss: 2.4872
# Train Batch 301/450 | Loss: 2.4669
# Train Batch 401/450 | Loss: 2.4027
# Train Batch 450/450 | Loss: 2.3641
# [Epoch 43] Train Loss: 2.4416 | Train Acc: 0.3416 | Train Perplexity: 11.4918
# [Validation] color: Loss=2.9477 | Acc=0.1419 | Perplexity=19.0617
# [Validation] shape: Loss=2.9583 | Acc=0.1466 | Perplexity=19.2646
# [Validation] quantity: Loss=2.9252 | Acc=0.1541 | Perplexity=18.6389
# [Validation Summary] Val Loss: 2.9437 | Val Acc: 0.1475 | Val Perplexity: 18.9884
#
# ----------------------------------------
#
# Epoch 44/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4861
# Train Batch 101/450 | Loss: 2.4379
# Train Batch 201/450 | Loss: 2.3781
# Train Batch 301/450 | Loss: 2.4682
# Train Batch 401/450 | Loss: 2.4162
# Train Batch 450/450 | Loss: 2.3966
# [Epoch 44] Train Loss: 2.4237 | Train Acc: 0.3494 | Train Perplexity: 11.2879
# [Validation] color: Loss=2.9748 | Acc=0.1416 | Perplexity=19.5864
# [Validation] shape: Loss=2.9766 | Acc=0.1481 | Perplexity=19.6207
# [Validation] quantity: Loss=2.9715 | Acc=0.1519 | Perplexity=19.5205
# [Validation Summary] Val Loss: 2.9743 | Val Acc: 0.1472 | Val Perplexity: 19.5758
#
# ----------------------------------------
#
# Epoch 45/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4585
# Train Batch 101/450 | Loss: 2.4274
# Train Batch 201/450 | Loss: 2.3826
# Train Batch 301/450 | Loss: 2.3741
# Train Batch 401/450 | Loss: 2.4209
# Train Batch 450/450 | Loss: 2.5100
# [Epoch 45] Train Loss: 2.4243 | Train Acc: 0.3490 | Train Perplexity: 11.2940
# [Validation] color: Loss=2.9005 | Acc=0.1369 | Perplexity=18.1834
# [Validation] shape: Loss=2.8994 | Acc=0.1469 | Perplexity=18.1627
# [Validation] quantity: Loss=2.8832 | Acc=0.1506 | Perplexity=17.8718
# [Validation Summary] Val Loss: 2.8944 | Val Acc: 0.1448 | Val Perplexity: 18.0726
#
# ----------------------------------------
#
# Epoch 46/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.4250
# Train Batch 101/450 | Loss: 2.5280
# Train Batch 201/450 | Loss: 2.5510
# Train Batch 301/450 | Loss: 2.4422
# Train Batch 401/450 | Loss: 2.4542
# Train Batch 450/450 | Loss: 2.3683
# [Epoch 46] Train Loss: 2.4091 | Train Acc: 0.3541 | Train Perplexity: 11.1237
# [Validation] color: Loss=2.9898 | Acc=0.1331 | Perplexity=19.8813
# [Validation] shape: Loss=2.9875 | Acc=0.1456 | Perplexity=19.8365
# [Validation] quantity: Loss=2.9616 | Acc=0.1509 | Perplexity=19.3290
# [Validation Summary] Val Loss: 2.9796 | Val Acc: 0.1432 | Val Perplexity: 19.6822
#
# ----------------------------------------
#
# Epoch 47/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3947
# Train Batch 101/450 | Loss: 2.2977
# Train Batch 201/450 | Loss: 2.3002
# Train Batch 301/450 | Loss: 2.3474
# Train Batch 401/450 | Loss: 2.3258
# Train Batch 450/450 | Loss: 2.4039
# [Epoch 47] Train Loss: 2.3675 | Train Acc: 0.3785 | Train Perplexity: 10.6707
# [Validation] color: Loss=3.0658 | Acc=0.1378 | Perplexity=21.4507
# [Validation] shape: Loss=3.0652 | Acc=0.1494 | Perplexity=21.4385
# [Validation] quantity: Loss=3.0241 | Acc=0.1562 | Perplexity=20.5758
# [Validation Summary] Val Loss: 3.0517 | Val Acc: 0.1478 | Val Perplexity: 21.1550
#
# ----------------------------------------
#
# Epoch 48/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2497
# Train Batch 101/450 | Loss: 2.3750
# Train Batch 201/450 | Loss: 2.3472
# Train Batch 301/450 | Loss: 2.2948
# Train Batch 401/450 | Loss: 2.6014
# Train Batch 450/450 | Loss: 2.3438
# [Epoch 48] Train Loss: 2.3447 | Train Acc: 0.3890 | Train Perplexity: 10.4301
# [Validation] color: Loss=3.0535 | Acc=0.1437 | Perplexity=21.1895
# [Validation] shape: Loss=3.0495 | Acc=0.1406 | Perplexity=21.1057
# [Validation] quantity: Loss=3.0187 | Acc=0.1556 | Perplexity=20.4641
# [Validation Summary] Val Loss: 3.0406 | Val Acc: 0.1467 | Val Perplexity: 20.9198
#
# ----------------------------------------
#
# Epoch 49/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3534
# Train Batch 101/450 | Loss: 2.2560
# Train Batch 201/450 | Loss: 2.3187
# Train Batch 301/450 | Loss: 2.5505
# Train Batch 401/450 | Loss: 2.2575
# Train Batch 450/450 | Loss: 2.2524
# [Epoch 49] Train Loss: 2.3221 | Train Acc: 0.3993 | Train Perplexity: 10.1972
# [Validation] color: Loss=3.0809 | Acc=0.1328 | Perplexity=21.7774
# [Validation] shape: Loss=3.0806 | Acc=0.1394 | Perplexity=21.7711
# [Validation] quantity: Loss=3.0491 | Acc=0.1516 | Perplexity=21.0964
# [Validation Summary] Val Loss: 3.0702 | Val Acc: 0.1413 | Val Perplexity: 21.5483
#
# ----------------------------------------
#
# Epoch 50/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3045
# Train Batch 101/450 | Loss: 2.2787
# Train Batch 201/450 | Loss: 2.1586
# Train Batch 301/450 | Loss: 2.2955
# Train Batch 401/450 | Loss: 2.4342
# Train Batch 450/450 | Loss: 2.2272
# [Epoch 50] Train Loss: 2.3084 | Train Acc: 0.4051 | Train Perplexity: 10.0585
# [Validation] color: Loss=3.1154 | Acc=0.1381 | Perplexity=22.5423
# [Validation] shape: Loss=3.1251 | Acc=0.1409 | Perplexity=22.7624
# [Validation] quantity: Loss=3.0913 | Acc=0.1512 | Perplexity=22.0054
# [Validation Summary] Val Loss: 3.1106 | Val Acc: 0.1434 | Val Perplexity: 22.4367
#
# ----------------------------------------
#
# Epoch 51/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2643
# Train Batch 101/450 | Loss: 2.2841
# Train Batch 201/450 | Loss: 2.2798
# Train Batch 301/450 | Loss: 2.1332
# Train Batch 401/450 | Loss: 2.4193
# Train Batch 450/450 | Loss: 2.3496
# [Epoch 51] Train Loss: 2.2839 | Train Acc: 0.4229 | Train Perplexity: 9.8152
# [Validation] color: Loss=3.1156 | Acc=0.1441 | Perplexity=22.5475
# [Validation] shape: Loss=3.1179 | Acc=0.1437 | Perplexity=22.5999
# [Validation] quantity: Loss=3.0834 | Acc=0.1588 | Perplexity=21.8320
# [Validation Summary] Val Loss: 3.1056 | Val Acc: 0.1489 | Val Perplexity: 22.3265
#
# ----------------------------------------
#
# Epoch 52/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2682
# Train Batch 101/450 | Loss: 2.1972
# Train Batch 201/450 | Loss: 2.1435
# Train Batch 301/450 | Loss: 2.2468
# Train Batch 401/450 | Loss: 2.2664
# Train Batch 450/450 | Loss: 2.1246
# [Epoch 52] Train Loss: 2.2633 | Train Acc: 0.4333 | Train Perplexity: 9.6144
# [Validation] color: Loss=3.1407 | Acc=0.1434 | Perplexity=23.1192
# [Validation] shape: Loss=3.1473 | Acc=0.1359 | Perplexity=23.2721
# [Validation] quantity: Loss=3.1132 | Acc=0.1600 | Perplexity=22.4928
# [Validation Summary] Val Loss: 3.1337 | Val Acc: 0.1465 | Val Perplexity: 22.9614
#
# ----------------------------------------
#
# Epoch 53/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0568
# Train Batch 101/450 | Loss: 2.1511
# Train Batch 201/450 | Loss: 2.1378
# Train Batch 301/450 | Loss: 2.3220
# Train Batch 401/450 | Loss: 2.4153
# Train Batch 450/450 | Loss: 2.3104
# [Epoch 53] Train Loss: 2.2421 | Train Acc: 0.4425 | Train Perplexity: 9.4134
# [Validation] color: Loss=3.1843 | Acc=0.1366 | Perplexity=24.1511
# [Validation] shape: Loss=3.1772 | Acc=0.1469 | Perplexity=23.9792
# [Validation] quantity: Loss=3.1613 | Acc=0.1506 | Perplexity=23.6001
# [Validation Summary] Val Loss: 3.1743 | Val Acc: 0.1447 | Val Perplexity: 23.9101
#
# ----------------------------------------
#
# Epoch 54/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2190
# Train Batch 101/450 | Loss: 2.1715
# Train Batch 201/450 | Loss: 2.3474
# Train Batch 301/450 | Loss: 2.3563
# Train Batch 401/450 | Loss: 2.3370
# Train Batch 450/450 | Loss: 2.2179
# [Epoch 54] Train Loss: 2.2191 | Train Acc: 0.4501 | Train Perplexity: 9.1987
# [Validation] color: Loss=3.2431 | Acc=0.1378 | Perplexity=25.6130
# [Validation] shape: Loss=3.2418 | Acc=0.1338 | Perplexity=25.5794
# [Validation] quantity: Loss=3.2003 | Acc=0.1491 | Perplexity=24.5395
# [Validation Summary] Val Loss: 3.2284 | Val Acc: 0.1402 | Val Perplexity: 25.2440
#
# ----------------------------------------
#
# Epoch 55/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3436
# Train Batch 101/450 | Loss: 2.1741
# Train Batch 201/450 | Loss: 2.1355
# Train Batch 301/450 | Loss: 2.2901
# Train Batch 401/450 | Loss: 2.2191
# Train Batch 450/450 | Loss: 2.2146
# [Epoch 55] Train Loss: 2.1980 | Train Acc: 0.4603 | Train Perplexity: 9.0073
# [Validation] color: Loss=3.2820 | Acc=0.1378 | Perplexity=26.6283
# [Validation] shape: Loss=3.2804 | Acc=0.1391 | Perplexity=26.5866
# [Validation] quantity: Loss=3.2295 | Acc=0.1559 | Perplexity=25.2673
# [Validation Summary] Val Loss: 3.2640 | Val Acc: 0.1443 | Val Perplexity: 26.1608
#
# ----------------------------------------
#
# Epoch 56/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0473
# Train Batch 101/450 | Loss: 2.2160
# Train Batch 201/450 | Loss: 2.4792
# Train Batch 301/450 | Loss: 2.2309
# Train Batch 401/450 | Loss: 2.2161
# Train Batch 450/450 | Loss: 2.3835
# [Epoch 56] Train Loss: 2.1761 | Train Acc: 0.4733 | Train Perplexity: 8.8119
# [Validation] color: Loss=3.3215 | Acc=0.1291 | Perplexity=27.7024
# [Validation] shape: Loss=3.3185 | Acc=0.1347 | Perplexity=27.6191
# [Validation] quantity: Loss=3.2662 | Acc=0.1619 | Perplexity=26.2111
# [Validation Summary] Val Loss: 3.3021 | Val Acc: 0.1419 | Val Perplexity: 27.1775
#
# ----------------------------------------
#
# Epoch 57/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9837
# Train Batch 101/450 | Loss: 2.0325
# Train Batch 201/450 | Loss: 2.0944
# Train Batch 301/450 | Loss: 2.3970
# Train Batch 401/450 | Loss: 2.2054
# Train Batch 450/450 | Loss: 2.2275
# [Epoch 57] Train Loss: 2.1450 | Train Acc: 0.4856 | Train Perplexity: 8.5421
# [Validation] color: Loss=3.3388 | Acc=0.1381 | Perplexity=28.1854
# [Validation] shape: Loss=3.3412 | Acc=0.1397 | Perplexity=28.2526
# [Validation] quantity: Loss=3.2989 | Acc=0.1550 | Perplexity=27.0835
# [Validation Summary] Val Loss: 3.3263 | Val Acc: 0.1443 | Val Perplexity: 27.8405
#
# ----------------------------------------
#
# Epoch 58/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0925
# Train Batch 101/450 | Loss: 2.2564
# Train Batch 201/450 | Loss: 1.9086
# Train Batch 301/450 | Loss: 2.1656
# Train Batch 401/450 | Loss: 2.2965
# Train Batch 450/450 | Loss: 2.1426
# [Epoch 58] Train Loss: 2.1366 | Train Acc: 0.4918 | Train Perplexity: 8.4703
# [Validation] color: Loss=3.3312 | Acc=0.1297 | Perplexity=27.9708
# [Validation] shape: Loss=3.3190 | Acc=0.1459 | Perplexity=27.6314
# [Validation] quantity: Loss=3.2684 | Acc=0.1541 | Perplexity=26.2698
# [Validation Summary] Val Loss: 3.3062 | Val Acc: 0.1432 | Val Perplexity: 27.2907
#
# ----------------------------------------
#
# Epoch 59/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.1280
# Train Batch 101/450 | Loss: 1.8837
# Train Batch 201/450 | Loss: 2.0403
# Train Batch 301/450 | Loss: 2.1163
# Train Batch 401/450 | Loss: 2.1324
# Train Batch 450/450 | Loss: 2.2231
# [Epoch 59] Train Loss: 2.1029 | Train Acc: 0.5080 | Train Perplexity: 8.1899
# [Validation] color: Loss=3.3731 | Acc=0.1372 | Perplexity=29.1693
# [Validation] shape: Loss=3.3864 | Acc=0.1369 | Perplexity=29.5581
# [Validation] quantity: Loss=3.3094 | Acc=0.1525 | Perplexity=27.3680
# [Validation Summary] Val Loss: 3.3563 | Val Acc: 0.1422 | Val Perplexity: 28.6985
#
# ----------------------------------------
#
# Epoch 60/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9054
# Train Batch 101/450 | Loss: 1.9831
# Train Batch 201/450 | Loss: 2.2003
# Train Batch 301/450 | Loss: 1.9549
# Train Batch 401/450 | Loss: 2.0972
# Train Batch 450/450 | Loss: 2.1607
# [Epoch 60] Train Loss: 2.0868 | Train Acc: 0.5161 | Train Perplexity: 8.0591
# [Validation] color: Loss=3.4255 | Acc=0.1378 | Perplexity=30.7394
# [Validation] shape: Loss=3.4301 | Acc=0.1369 | Perplexity=30.8805
# [Validation] quantity: Loss=3.3665 | Acc=0.1597 | Perplexity=28.9767
# [Validation Summary] Val Loss: 3.4074 | Val Acc: 0.1448 | Val Perplexity: 30.1989
#
# ----------------------------------------
#
# Epoch 61/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0452
# Train Batch 101/450 | Loss: 2.1078
# Train Batch 201/450 | Loss: 1.8378
# Train Batch 301/450 | Loss: 2.0222
# Train Batch 401/450 | Loss: 1.9746
# Train Batch 450/450 | Loss: 2.0033
# [Epoch 61] Train Loss: 2.0626 | Train Acc: 0.5263 | Train Perplexity: 7.8664
# [Validation] color: Loss=3.4567 | Acc=0.1391 | Perplexity=31.7114
# [Validation] shape: Loss=3.4682 | Acc=0.1409 | Perplexity=32.0784
# [Validation] quantity: Loss=3.4250 | Acc=0.1531 | Perplexity=30.7229
# [Validation Summary] Val Loss: 3.4500 | Val Acc: 0.1444 | Val Perplexity: 31.5042
#
# ----------------------------------------
#
# Epoch 62/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9601
# Train Batch 101/450 | Loss: 2.0210
# Train Batch 201/450 | Loss: 2.0239
# Train Batch 301/450 | Loss: 2.0104
# Train Batch 401/450 | Loss: 2.1017
# Train Batch 450/450 | Loss: 2.0880
# [Epoch 62] Train Loss: 2.0417 | Train Acc: 0.5395 | Train Perplexity: 7.7035
# [Validation] color: Loss=3.5086 | Acc=0.1344 | Perplexity=33.4021
# [Validation] shape: Loss=3.5126 | Acc=0.1412 | Perplexity=33.5368
# [Validation] quantity: Loss=3.4432 | Acc=0.1566 | Perplexity=31.2873
# [Validation Summary] Val Loss: 3.4882 | Val Acc: 0.1441 | Val Perplexity: 32.7421
#
# ----------------------------------------
#
# Epoch 63/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9298
# Train Batch 101/450 | Loss: 1.9396
# Train Batch 201/450 | Loss: 1.9308
# Train Batch 301/450 | Loss: 2.1305
# Train Batch 401/450 | Loss: 1.9767
# Train Batch 450/450 | Loss: 1.8639
# [Epoch 63] Train Loss: 2.0249 | Train Acc: 0.5480 | Train Perplexity: 7.5753
# [Validation] color: Loss=3.4960 | Acc=0.1334 | Perplexity=32.9821
# [Validation] shape: Loss=3.5077 | Acc=0.1422 | Perplexity=33.3704
# [Validation] quantity: Loss=3.4447 | Acc=0.1550 | Perplexity=31.3338
# [Validation Summary] Val Loss: 3.4828 | Val Acc: 0.1435 | Val Perplexity: 32.5621
#
# ----------------------------------------
#
# Epoch 64/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0839
# Train Batch 101/450 | Loss: 2.0361
# Train Batch 201/450 | Loss: 2.2431
# Train Batch 301/450 | Loss: 2.0559
# Train Batch 401/450 | Loss: 2.0221
# Train Batch 450/450 | Loss: 1.9532
# [Epoch 64] Train Loss: 2.0054 | Train Acc: 0.5488 | Train Perplexity: 7.4293
# [Validation] color: Loss=3.5899 | Acc=0.1375 | Perplexity=36.2319
# [Validation] shape: Loss=3.6014 | Acc=0.1347 | Perplexity=36.6489
# [Validation] quantity: Loss=3.5296 | Acc=0.1609 | Perplexity=34.1106
# [Validation Summary] Val Loss: 3.5736 | Val Acc: 0.1444 | Val Perplexity: 35.6638
#
# ----------------------------------------
#
# Epoch 65/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0121
# Train Batch 101/450 | Loss: 1.9395
# Train Batch 201/450 | Loss: 1.8497
# Train Batch 301/450 | Loss: 2.0191
# Train Batch 401/450 | Loss: 1.9005
# Train Batch 450/450 | Loss: 2.1388
# [Epoch 65] Train Loss: 1.9728 | Train Acc: 0.5694 | Train Perplexity: 7.1910
# [Validation] color: Loss=3.6259 | Acc=0.1400 | Perplexity=37.5585
# [Validation] shape: Loss=3.6479 | Acc=0.1363 | Perplexity=38.3926
# [Validation] quantity: Loss=3.5682 | Acc=0.1569 | Perplexity=35.4519
# [Validation Summary] Val Loss: 3.6140 | Val Acc: 0.1444 | Val Perplexity: 37.1343
#
# ----------------------------------------
#
# Epoch 66/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9984
# Train Batch 101/450 | Loss: 2.1071
# Train Batch 201/450 | Loss: 1.9028
# Train Batch 301/450 | Loss: 2.1211
# Train Batch 401/450 | Loss: 2.0211
# Train Batch 450/450 | Loss: 2.1109
# [Epoch 66] Train Loss: 1.9608 | Train Acc: 0.5728 | Train Perplexity: 7.1052
# [Validation] color: Loss=3.6381 | Acc=0.1369 | Perplexity=38.0179
# [Validation] shape: Loss=3.6331 | Acc=0.1375 | Perplexity=37.8293
# [Validation] quantity: Loss=3.5603 | Acc=0.1541 | Perplexity=35.1745
# [Validation Summary] Val Loss: 3.6105 | Val Acc: 0.1428 | Val Perplexity: 37.0073
#
# ----------------------------------------
#
# Epoch 67/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8356
# Train Batch 101/450 | Loss: 1.9972
# Train Batch 201/450 | Loss: 1.8236
# Train Batch 301/450 | Loss: 1.9554
# Train Batch 401/450 | Loss: 2.4664
# Train Batch 450/450 | Loss: 2.2786
# [Epoch 67] Train Loss: 2.0604 | Train Acc: 0.5319 | Train Perplexity: 7.8495
# [Validation] color: Loss=3.2292 | Acc=0.1313 | Perplexity=25.2590
# [Validation] shape: Loss=3.2190 | Acc=0.1375 | Perplexity=25.0034
# [Validation] quantity: Loss=3.1659 | Acc=0.1622 | Perplexity=23.7105
# [Validation Summary] Val Loss: 3.2047 | Val Acc: 0.1436 | Val Perplexity: 24.6577
#
# ----------------------------------------
#
# Epoch 68/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3179
# Train Batch 101/450 | Loss: 2.2153
# Train Batch 201/450 | Loss: 2.1329
# Train Batch 301/450 | Loss: 2.1457
# Train Batch 401/450 | Loss: 2.0407
# Train Batch 450/450 | Loss: 2.0719
# [Epoch 68] Train Loss: 2.0935 | Train Acc: 0.5146 | Train Perplexity: 8.1133
# [Validation] color: Loss=3.5127 | Acc=0.1397 | Perplexity=33.5386
# [Validation] shape: Loss=3.5172 | Acc=0.1328 | Perplexity=33.6899
# [Validation] quantity: Loss=3.4328 | Acc=0.1600 | Perplexity=30.9642
# [Validation Summary] Val Loss: 3.4876 | Val Acc: 0.1442 | Val Perplexity: 32.7309
#
# ----------------------------------------
#
# Epoch 69/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9887
# Train Batch 101/450 | Loss: 1.9477
# Train Batch 201/450 | Loss: 2.0530
# Train Batch 301/450 | Loss: 2.0400
# Train Batch 401/450 | Loss: 1.7079
# Train Batch 450/450 | Loss: 1.8311
# [Epoch 69] Train Loss: 1.9924 | Train Acc: 0.5608 | Train Perplexity: 7.3328
# [Validation] color: Loss=3.6324 | Acc=0.1450 | Perplexity=37.8043
# [Validation] shape: Loss=3.6354 | Acc=0.1366 | Perplexity=37.9174
# [Validation] quantity: Loss=3.5443 | Acc=0.1622 | Perplexity=34.6139
# [Validation Summary] Val Loss: 3.6040 | Val Acc: 0.1479 | Val Perplexity: 36.7785
#
# ----------------------------------------
#
# Epoch 70/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9202
# Train Batch 101/450 | Loss: 2.0072
# Train Batch 201/450 | Loss: 1.8825
# Train Batch 301/450 | Loss: 1.9585
# Train Batch 401/450 | Loss: 1.8515
# Train Batch 450/450 | Loss: 2.1265
# [Epoch 70] Train Loss: 1.9385 | Train Acc: 0.5847 | Train Perplexity: 6.9486
# [Validation] color: Loss=3.7177 | Acc=0.1394 | Perplexity=41.1689
# [Validation] shape: Loss=3.7204 | Acc=0.1375 | Perplexity=41.2808
# [Validation] quantity: Loss=3.6298 | Acc=0.1575 | Perplexity=37.7038
# [Validation Summary] Val Loss: 3.6893 | Val Acc: 0.1448 | Val Perplexity: 40.0512
#
# ----------------------------------------
#
# Epoch 71/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8612
# Train Batch 101/450 | Loss: 1.6285
# Train Batch 201/450 | Loss: 1.8696
# Train Batch 301/450 | Loss: 2.0630
# Train Batch 401/450 | Loss: 2.1317
# Train Batch 450/450 | Loss: 2.0066
# [Epoch 71] Train Loss: 1.9091 | Train Acc: 0.6002 | Train Perplexity: 6.7473
# [Validation] color: Loss=3.7093 | Acc=0.1403 | Perplexity=40.8269
# [Validation] shape: Loss=3.7274 | Acc=0.1388 | Perplexity=41.5718
# [Validation] quantity: Loss=3.6365 | Acc=0.1550 | Perplexity=37.9576
# [Validation Summary] Val Loss: 3.6911 | Val Acc: 0.1447 | Val Perplexity: 40.1188
#
# ----------------------------------------
#
# Epoch 72/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0178
# Train Batch 101/450 | Loss: 2.0714
# Train Batch 201/450 | Loss: 1.8339
# Train Batch 301/450 | Loss: 2.1472
# Train Batch 401/450 | Loss: 1.8809
# Train Batch 450/450 | Loss: 1.9604
# [Epoch 72] Train Loss: 1.9129 | Train Acc: 0.5945 | Train Perplexity: 6.7724
# [Validation] color: Loss=3.6956 | Acc=0.1403 | Perplexity=40.2681
# [Validation] shape: Loss=3.7225 | Acc=0.1384 | Perplexity=41.3677
# [Validation] quantity: Loss=3.6314 | Acc=0.1556 | Perplexity=37.7651
# [Validation Summary] Val Loss: 3.6831 | Val Acc: 0.1448 | Val Perplexity: 39.8003
#
# ----------------------------------------
#
# Epoch 73/100
# ----------------------------------------
# ...
# Train Batch 1/450 | Loss: 1.7576
# Train Batch 101/450 | Loss: 1.9620
# Train Batch 201/450 | Loss: 1.8880
# Train Batch 301/450 | Loss: 2.2886
# Train Batch 401/450 | Loss: 1.8856
# Train Batch 450/450 | Loss: 2.0922
# [Epoch 77] Train Loss: 1.9251 | Train Acc: 0.5883 | Train Perplexity: 6.8558
# [Validation] color: Loss=3.6851 | Acc=0.1466 | Perplexity=39.8477
# [Validation] shape: Loss=3.7097 | Acc=0.1437 | Perplexity=40.8428
# [Validation] quantity: Loss=3.6372 | Acc=0.1597 | Perplexity=37.9866
# [Validation Summary] Val Loss: 3.6773 | Val Acc: 0.1500 | Val Perplexity: 39.5590
#
# ----------------------------------------
#
# Epoch 78/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9774
# Train Batch 101/450 | Loss: 2.1240
# Train Batch 201/450 | Loss: 1.9847
# Train Batch 301/450 | Loss: 1.8160
# Train Batch 401/450 | Loss: 1.9226
# Train Batch 450/450 | Loss: 1.9906
# [Epoch 78] Train Loss: 1.8908 | Train Acc: 0.6047 | Train Perplexity: 6.6246
# [Validation] color: Loss=3.7921 | Acc=0.1447 | Perplexity=44.3514
# [Validation] shape: Loss=3.8193 | Acc=0.1444 | Perplexity=45.5710
# [Validation] quantity: Loss=3.7331 | Acc=0.1544 | Perplexity=41.8075
# [Validation Summary] Val Loss: 3.7815 | Val Acc: 0.1478 | Val Perplexity: 43.9100
#
# ----------------------------------------
#
# Epoch 79/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6271
# Train Batch 101/450 | Loss: 1.9515
# Train Batch 201/450 | Loss: 1.9841
# Train Batch 301/450 | Loss: 1.8155
# Train Batch 401/450 | Loss: 1.8936
# Train Batch 450/450 | Loss: 1.7872
# [Epoch 79] Train Loss: 1.8720 | Train Acc: 0.6122 | Train Perplexity: 6.5010
# [Validation] color: Loss=3.7910 | Acc=0.1462 | Perplexity=44.2985
# [Validation] shape: Loss=3.8169 | Acc=0.1441 | Perplexity=45.4616
# [Validation] quantity: Loss=3.7243 | Acc=0.1584 | Perplexity=41.4435
# [Validation Summary] Val Loss: 3.7774 | Val Acc: 0.1496 | Val Perplexity: 43.7345
#
# ----------------------------------------
#
# Epoch 80/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8308
# Train Batch 101/450 | Loss: 1.7549
# Train Batch 201/450 | Loss: 2.0451
# Train Batch 301/450 | Loss: 1.8140
# Train Batch 401/450 | Loss: 2.1323
# Train Batch 450/450 | Loss: 1.7502
# [Epoch 80] Train Loss: 1.8512 | Train Acc: 0.6207 | Train Perplexity: 6.3673
# [Validation] color: Loss=3.7905 | Acc=0.1434 | Perplexity=44.2771
# [Validation] shape: Loss=3.8258 | Acc=0.1406 | Perplexity=45.8716
# [Validation] quantity: Loss=3.7250 | Acc=0.1606 | Perplexity=41.4695
# [Validation Summary] Val Loss: 3.7804 | Val Acc: 0.1482 | Val Perplexity: 43.8727
#
# ----------------------------------------
#
# Epoch 81/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6725
# Train Batch 101/450 | Loss: 1.7963
# Train Batch 201/450 | Loss: 1.7160
# Train Batch 301/450 | Loss: 2.0698
# Train Batch 401/450 | Loss: 1.9424
# Train Batch 450/450 | Loss: 1.8562
# [Epoch 81] Train Loss: 1.8235 | Train Acc: 0.6352 | Train Perplexity: 6.1935
# [Validation] color: Loss=3.9056 | Acc=0.1403 | Perplexity=49.6800
# [Validation] shape: Loss=3.9319 | Acc=0.1453 | Perplexity=51.0033
# [Validation] quantity: Loss=3.8468 | Acc=0.1634 | Perplexity=46.8430
# [Validation Summary] Val Loss: 3.8948 | Val Acc: 0.1497 | Val Perplexity: 49.1754
#
# ----------------------------------------
#
# Epoch 82/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6470
# Train Batch 101/450 | Loss: 1.7057
# Train Batch 201/450 | Loss: 1.8798
# Train Batch 301/450 | Loss: 1.6872
# Train Batch 401/450 | Loss: 1.8110
# Train Batch 450/450 | Loss: 1.9518
# [Epoch 82] Train Loss: 1.8053 | Train Acc: 0.6430 | Train Perplexity: 6.0817
# [Validation] color: Loss=3.8704 | Acc=0.1381 | Perplexity=47.9638
# [Validation] shape: Loss=3.8896 | Acc=0.1388 | Perplexity=48.8931
# [Validation] quantity: Loss=3.7984 | Acc=0.1606 | Perplexity=44.6296
# [Validation Summary] Val Loss: 3.8528 | Val Acc: 0.1458 | Val Perplexity: 47.1622
#
# ----------------------------------------
#
# Epoch 83/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6795
# Train Batch 101/450 | Loss: 1.8815
# Train Batch 201/450 | Loss: 1.8114
# Train Batch 301/450 | Loss: 1.7596
# Train Batch 401/450 | Loss: 1.8031
# Train Batch 450/450 | Loss: 1.9434
# [Epoch 83] Train Loss: 1.7937 | Train Acc: 0.6445 | Train Perplexity: 6.0118
# [Validation] color: Loss=3.8853 | Acc=0.1406 | Perplexity=48.6807
# [Validation] shape: Loss=3.9308 | Acc=0.1437 | Perplexity=50.9459
# [Validation] quantity: Loss=3.8380 | Acc=0.1547 | Perplexity=46.4346
# [Validation Summary] Val Loss: 3.8847 | Val Acc: 0.1464 | Val Perplexity: 48.6871
#
# ----------------------------------------
#
# Epoch 84/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5708
# Train Batch 101/450 | Loss: 1.8830
# Train Batch 201/450 | Loss: 1.8022
# Train Batch 301/450 | Loss: 1.7879
# Train Batch 401/450 | Loss: 1.7281
# Train Batch 450/450 | Loss: 1.6901
# [Epoch 84] Train Loss: 1.7944 | Train Acc: 0.6468 | Train Perplexity: 6.0157
# [Validation] color: Loss=3.9593 | Acc=0.1453 | Perplexity=52.4196
# [Validation] shape: Loss=3.9843 | Acc=0.1397 | Perplexity=53.7489
# [Validation] quantity: Loss=3.9169 | Acc=0.1525 | Perplexity=50.2429
# [Validation Summary] Val Loss: 3.9535 | Val Acc: 0.1458 | Val Perplexity: 52.1372
#
# ----------------------------------------
#
# Epoch 85/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8423
# Train Batch 101/450 | Loss: 1.6779
# Train Batch 201/450 | Loss: 1.6329
# Train Batch 301/450 | Loss: 1.6875
# Train Batch 401/450 | Loss: 1.5576
# Train Batch 450/450 | Loss: 1.9463
# [Epoch 85] Train Loss: 1.7833 | Train Acc: 0.6510 | Train Perplexity: 5.9493
# [Validation] color: Loss=3.9204 | Acc=0.1419 | Perplexity=50.4214
# [Validation] shape: Loss=3.9433 | Acc=0.1431 | Perplexity=51.5866
# [Validation] quantity: Loss=3.8749 | Acc=0.1556 | Perplexity=48.1777
# [Validation Summary] Val Loss: 3.9129 | Val Acc: 0.1469 | Val Perplexity: 50.0619
#
# ----------------------------------------
#
# Epoch 86/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8942
# Train Batch 101/450 | Loss: 1.7551
# Train Batch 201/450 | Loss: 1.6890
# Train Batch 301/450 | Loss: 2.1343
# Train Batch 401/450 | Loss: 1.6635
# Train Batch 450/450 | Loss: 1.5650
# [Epoch 86] Train Loss: 1.7579 | Train Acc: 0.6625 | Train Perplexity: 5.8001
# [Validation] color: Loss=3.9764 | Acc=0.1384 | Perplexity=53.3244
# [Validation] shape: Loss=4.0107 | Acc=0.1419 | Perplexity=55.1836
# [Validation] quantity: Loss=3.9238 | Acc=0.1559 | Perplexity=50.5931
# [Validation Summary] Val Loss: 3.9703 | Val Acc: 0.1454 | Val Perplexity: 53.0337
#
# ----------------------------------------
#
# Epoch 87/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8409
# Train Batch 101/450 | Loss: 1.5078
# Train Batch 201/450 | Loss: 1.8677
# Train Batch 301/450 | Loss: 1.7896
# Train Batch 401/450 | Loss: 1.8737
# Train Batch 450/450 | Loss: 1.7997
# [Epoch 87] Train Loss: 1.7600 | Train Acc: 0.6605 | Train Perplexity: 5.8126
# [Validation] color: Loss=3.9285 | Acc=0.1409 | Perplexity=50.8298
# [Validation] shape: Loss=3.9869 | Acc=0.1444 | Perplexity=53.8856
# [Validation] quantity: Loss=3.8934 | Acc=0.1553 | Perplexity=49.0788
# [Validation Summary] Val Loss: 3.9363 | Val Acc: 0.1469 | Val Perplexity: 51.2647
#
# ----------------------------------------
#
# Epoch 88/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5286
# Train Batch 101/450 | Loss: 1.6790
# Train Batch 201/450 | Loss: 1.6166
# Train Batch 301/450 | Loss: 1.6276
# Train Batch 401/450 | Loss: 1.6191
# Train Batch 450/450 | Loss: 1.9327
# [Epoch 88] Train Loss: 1.7459 | Train Acc: 0.6655 | Train Perplexity: 5.7311
# [Validation] color: Loss=3.9582 | Acc=0.1434 | Perplexity=52.3646
# [Validation] shape: Loss=3.9910 | Acc=0.1412 | Perplexity=54.1071
# [Validation] quantity: Loss=3.8872 | Acc=0.1581 | Perplexity=48.7749
# [Validation Summary] Val Loss: 3.9455 | Val Acc: 0.1476 | Val Perplexity: 51.7489
#
# ----------------------------------------
#
# Epoch 89/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8017
# Train Batch 101/450 | Loss: 1.6544
# Train Batch 201/450 | Loss: 1.8068
# Train Batch 301/450 | Loss: 1.5543
# Train Batch 401/450 | Loss: 1.7698
# Train Batch 450/450 | Loss: 1.8822
# [Epoch 89] Train Loss: 1.7300 | Train Acc: 0.6700 | Train Perplexity: 5.6405
# [Validation] color: Loss=4.0624 | Acc=0.1394 | Perplexity=58.1133
# [Validation] shape: Loss=4.1071 | Acc=0.1431 | Perplexity=60.7720
# [Validation] quantity: Loss=3.9875 | Acc=0.1562 | Perplexity=53.9225
# [Validation Summary] Val Loss: 4.0524 | Val Acc: 0.1462 | Val Perplexity: 57.6026
#
# ----------------------------------------
#
# Epoch 90/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9300
# Train Batch 101/450 | Loss: 1.7117
# Train Batch 201/450 | Loss: 1.8299
# Train Batch 301/450 | Loss: 1.8472
# Train Batch 401/450 | Loss: 1.7008
# Train Batch 450/450 | Loss: 1.9107
# [Epoch 90] Train Loss: 1.7312 | Train Acc: 0.6718 | Train Perplexity: 5.6471
# [Validation] color: Loss=3.9885 | Acc=0.1425 | Perplexity=53.9754
# [Validation] shape: Loss=4.0138 | Acc=0.1441 | Perplexity=55.3560
# [Validation] quantity: Loss=3.9400 | Acc=0.1509 | Perplexity=51.4196
# [Validation Summary] Val Loss: 3.9808 | Val Acc: 0.1458 | Val Perplexity: 53.5837
#
# ----------------------------------------
#
# Epoch 91/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5827
# Train Batch 101/450 | Loss: 1.6985
# Train Batch 201/450 | Loss: 1.9238
# Train Batch 301/450 | Loss: 1.6574
# Train Batch 401/450 | Loss: 1.7387
# Train Batch 450/450 | Loss: 1.7817
# [Epoch 91] Train Loss: 1.7236 | Train Acc: 0.6727 | Train Perplexity: 5.6046
# [Validation] color: Loss=4.0407 | Acc=0.1431 | Perplexity=56.8685
# [Validation] shape: Loss=4.0524 | Acc=0.1406 | Perplexity=57.5364
# [Validation] quantity: Loss=3.9703 | Acc=0.1491 | Perplexity=53.0003
# [Validation Summary] Val Loss: 4.0212 | Val Acc: 0.1443 | Val Perplexity: 55.8017
#
# ----------------------------------------
#
# Epoch 92/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6643
# Train Batch 101/450 | Loss: 1.6344
# Train Batch 201/450 | Loss: 2.0053
# Train Batch 301/450 | Loss: 1.9059
# Train Batch 401/450 | Loss: 1.7605
# Train Batch 450/450 | Loss: 1.6776
# [Epoch 92] Train Loss: 1.7148 | Train Acc: 0.6776 | Train Perplexity: 5.5553
# [Validation] color: Loss=4.0778 | Acc=0.1347 | Perplexity=59.0149
# [Validation] shape: Loss=4.1093 | Acc=0.1400 | Perplexity=60.9037
# [Validation] quantity: Loss=3.9931 | Acc=0.1506 | Perplexity=54.2219
# [Validation Summary] Val Loss: 4.0601 | Val Acc: 0.1418 | Val Perplexity: 58.0468
#
# ----------------------------------------
#
# Epoch 93/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6158
# Train Batch 101/450 | Loss: 1.5899
# Train Batch 201/450 | Loss: 1.8068
# Train Batch 301/450 | Loss: 1.6341
# Train Batch 401/450 | Loss: 1.7379
# Train Batch 450/450 | Loss: 1.5214
# [Epoch 93] Train Loss: 1.6920 | Train Acc: 0.6888 | Train Perplexity: 5.4301
# [Validation] color: Loss=4.0748 | Acc=0.1394 | Perplexity=58.8380
# [Validation] shape: Loss=4.0892 | Acc=0.1428 | Perplexity=59.6897
# [Validation] quantity: Loss=4.0037 | Acc=0.1525 | Perplexity=54.8028
# [Validation Summary] Val Loss: 4.0559 | Val Acc: 0.1449 | Val Perplexity: 57.7768
#
# ----------------------------------------
#
# Epoch 94/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5104
# Train Batch 101/450 | Loss: 1.5920
# Train Batch 201/450 | Loss: 1.8017
# Train Batch 301/450 | Loss: 1.7289
# Train Batch 401/450 | Loss: 1.6957
# Train Batch 450/450 | Loss: 1.8706
# [Epoch 94] Train Loss: 1.6889 | Train Acc: 0.6901 | Train Perplexity: 5.4137
# [Validation] color: Loss=4.1041 | Acc=0.1394 | Perplexity=60.5862
# [Validation] shape: Loss=4.1480 | Acc=0.1466 | Perplexity=63.3042
# [Validation] quantity: Loss=4.0548 | Acc=0.1525 | Perplexity=57.6761
# [Validation Summary] Val Loss: 4.1023 | Val Acc: 0.1461 | Val Perplexity: 60.5222
#
# ----------------------------------------
#
# Epoch 95/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.7245
# Train Batch 101/450 | Loss: 1.6508
# Train Batch 201/450 | Loss: 1.6302
# Train Batch 301/450 | Loss: 1.6686
# Train Batch 401/450 | Loss: 1.6818
# Train Batch 450/450 | Loss: 1.5796
# [Epoch 95] Train Loss: 1.6773 | Train Acc: 0.6947 | Train Perplexity: 5.3512
# [Validation] color: Loss=4.0914 | Acc=0.1422 | Perplexity=59.8228
# [Validation] shape: Loss=4.1105 | Acc=0.1422 | Perplexity=60.9748
# [Validation] quantity: Loss=4.0031 | Acc=0.1541 | Perplexity=54.7694
# [Validation Summary] Val Loss: 4.0683 | Val Acc: 0.1461 | Val Perplexity: 58.5223
#
# ----------------------------------------
#
# Epoch 96/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6600
# Train Batch 101/450 | Loss: 1.7954
# Train Batch 201/450 | Loss: 1.7015
# Train Batch 301/450 | Loss: 1.6245
# Train Batch 401/450 | Loss: 1.8815
# Train Batch 450/450 | Loss: 1.6199
# [Epoch 96] Train Loss: 1.6708 | Train Acc: 0.6962 | Train Perplexity: 5.3167
# [Validation] color: Loss=4.0677 | Acc=0.1394 | Perplexity=58.4243
# [Validation] shape: Loss=4.0869 | Acc=0.1406 | Perplexity=59.5543
# [Validation] quantity: Loss=4.0079 | Acc=0.1487 | Perplexity=55.0287
# [Validation Summary] Val Loss: 4.0542 | Val Acc: 0.1429 | Val Perplexity: 57.6691
#
# ----------------------------------------
#
# Epoch 97/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6277
# Train Batch 101/450 | Loss: 1.6024
# Train Batch 201/450 | Loss: 1.6751
# Train Batch 301/450 | Loss: 1.6046
# Train Batch 401/450 | Loss: 1.8477
# Train Batch 450/450 | Loss: 1.6586
# [Epoch 97] Train Loss: 1.6501 | Train Acc: 0.7052 | Train Perplexity: 5.2077
# [Validation] color: Loss=4.2130 | Acc=0.1356 | Perplexity=67.5562
# [Validation] shape: Loss=4.2289 | Acc=0.1431 | Perplexity=68.6450
# [Validation] quantity: Loss=4.1288 | Acc=0.1522 | Perplexity=62.1042
# [Validation Summary] Val Loss: 4.1902 | Val Acc: 0.1436 | Val Perplexity: 66.1018
#
# ----------------------------------------
#
# Epoch 98/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5557
# Train Batch 101/450 | Loss: 1.4669
# Train Batch 201/450 | Loss: 1.6685
# Train Batch 301/450 | Loss: 1.6868
# Train Batch 401/450 | Loss: 1.8195
# Train Batch 450/450 | Loss: 1.6713
# [Epoch 98] Train Loss: 1.6459 | Train Acc: 0.7081 | Train Perplexity: 5.1856
# [Validation] color: Loss=4.2362 | Acc=0.1359 | Perplexity=69.1418
# [Validation] shape: Loss=4.2693 | Acc=0.1416 | Perplexity=71.4696
# [Validation] quantity: Loss=4.1682 | Acc=0.1425 | Perplexity=64.5977
# [Validation Summary] Val Loss: 4.2245 | Val Acc: 0.1400 | Val Perplexity: 68.4030
#
# ----------------------------------------
#
# Epoch 99/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5331
# Train Batch 101/450 | Loss: 1.6700
# Train Batch 201/450 | Loss: 1.6702
# Train Batch 301/450 | Loss: 1.5965
# Train Batch 401/450 | Loss: 1.7842
# Train Batch 450/450 | Loss: 1.6042
# [Epoch 99] Train Loss: 1.6269 | Train Acc: 0.7170 | Train Perplexity: 5.0879
# [Validation] color: Loss=4.3199 | Acc=0.1419 | Perplexity=75.1822
# [Validation] shape: Loss=4.3257 | Acc=0.1469 | Perplexity=75.6188
# [Validation] quantity: Loss=4.2261 | Acc=0.1512 | Perplexity=68.4510
# [Validation Summary] Val Loss: 4.2906 | Val Acc: 0.1467 | Val Perplexity: 73.0840
#
# ----------------------------------------
#
# Epoch 100/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6627
# Train Batch 101/450 | Loss: 1.6389
# Train Batch 201/450 | Loss: 1.6455
# Train Batch 301/450 | Loss: 1.5703
# Train Batch 401/450 | Loss: 1.7955
# Train Batch 450/450 | Loss: 1.6744
# [Epoch 100] Train Loss: 1.6155 | Train Acc: 0.7223 | Train Perplexity: 5.0302
# [Validation] color: Loss=4.2292 | Acc=0.1428 | Perplexity=68.6605
# [Validation] shape: Loss=4.2482 | Acc=0.1444 | Perplexity=69.9828
# [Validation] quantity: Loss=4.1381 | Acc=0.1562 | Perplexity=62.6810
# [Validation Summary] Val Loss: 4.2052 | Val Acc: 0.1478 | Val Perplexity: 67.1081
#
# ----------------------------------------
#
# Training complete
# [Test] Loss: 4.2094 | Acc: 0.1490 | Perplexity: 67.3159

# %% [markdown]
# ### 3. Save Training & Test Results

# %%
import json

# %%
for i, result in enumerate(results):
    with open(f"./../../results/scaling_laws/ce_transformer_performace_N-7.json", "w") as file:
        json.dump(result, file, indent=4)
