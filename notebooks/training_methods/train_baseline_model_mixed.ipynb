# %%
import sys
import os
import torch as T
import numpy as np
import random

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../..")))

# %%
def set_global_seed(seed: int):
    T.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)

    if T.cuda.is_available():
        T.cuda.manual_seed_all(seed)

# %%
SEED = 42

device = T.device('cuda' if T.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

set_global_seed(SEED)
# Out:
# Using device: cuda

# %% [markdown]
# ## Dataset Loading

# %%
from torch.utils.data import DataLoader
from datasets.custom_dataset import CustomWCSTDataset

# %% [markdown]
# ### 1. Dataset Hyperparameters

# %%
BATCH_SIZE = 64
TOTAL_BATCHES = 750
TRAIN_TEST_SPLIT_RATIO = 0.6
VALIDATION_TEST_SPLIT_RATIO = 0.5

# %% [markdown]
# ### 2. Loading Dataset

# %%
train_size = int(TOTAL_BATCHES * TRAIN_TEST_SPLIT_RATIO)
validation_size = int((TOTAL_BATCHES - train_size) * VALIDATION_TEST_SPLIT_RATIO)
test_size = TOTAL_BATCHES - train_size - validation_size

mixed_train_dataset = CustomWCSTDataset(total_batches=train_size, sample_batch_size=BATCH_SIZE)

mixed_train_loader = DataLoader(mixed_train_dataset, batch_size=BATCH_SIZE, shuffle=True)

validation_datasets = {
    "color": CustomWCSTDataset(total_batches=validation_size // 3, fixed_context=0, sample_batch_size=BATCH_SIZE, allow_switch=False),
    "shape": CustomWCSTDataset(total_batches=validation_size // 3, fixed_context=1, sample_batch_size=BATCH_SIZE, allow_switch=False),
    "quantity": CustomWCSTDataset(total_batches=validation_size // 3, fixed_context=2, sample_batch_size=BATCH_SIZE, allow_switch=False)
}

validation_loaders = {
    ctx: DataLoader(ds, batch_size=BATCH_SIZE, shuffle=True)
    for ctx, ds in validation_datasets.items()
}

test_dataset = CustomWCSTDataset(
        total_batches=test_size, sample_batch_size=BATCH_SIZE
    )
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# [Dataset Init] Fixed context: 0
# [Dataset Init] Fixed context: 1
# [Dataset Init] Fixed context: 2
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Fixed context: 0
# [Dataset Init] Fixed context: 1
# [Dataset Init] Fixed context: 2
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 2
# [Dataset Init] Context switched -> 0
# [Dataset Init] Context switched -> 1
# [Dataset Init] Context switched -> 2

# %% [markdown]
# ## Transformer Model Creation & Training

# %%
import itertools
import numpy as np
from collections import defaultdict
from torch.utils.data import DataLoader
from torch import nn, optim

from src.transformer import BaselineTransformer

# %% [markdown]
# ### 1. Train, Validate and Test Model Functions

# %%
def validate_per_context(
        model: nn.Module, criterion: nn.CrossEntropyLoss, loaders: dict[str, DataLoader], device: T.device | str ="cpu"
    ):
    model.eval()
    results = {}

    with T.no_grad():
        for ctx_name, loader in loaders.items():
            total_loss, total_correct, total_samples = 0.0, 0, 0
            for input_seq, target in loader:
                input_seq, target = input_seq.to(device), target.view(-1).to(device)

                logits = model(input_seq)
                logits = logits[:, -1, :]
                
                loss = criterion(logits, target)

                preds = logits.argmax(dim=1)
                total_loss += loss.item() * target.size(0)
                total_correct += (preds == target).sum().item()
                total_samples += target.size(0)

            avg_loss = total_loss / total_samples
            avg_acc = total_correct / total_samples

            results[ctx_name] = {
                "loss": avg_loss,
                "acc": avg_acc,
                "perplexity": np.exp(avg_loss)
            }
    return results

# %%
def train_model(
    train_loader: DataLoader, validation_loaders: dict[str, DataLoader], model: nn.Module, criterion: nn.CrossEntropyLoss, 
    optimizer: optim.Optimizer, max_epochs: int = 20, device: str | T.device = "cpu"
):
    history = defaultdict(list)

    for epoch in range(max_epochs):
        print(f"\nEpoch {epoch + 1}/{max_epochs}")
        print("-" * 40)

        # --- Training ---
        model.train()
        epoch_train_losses = []
        total_correct = 0
        total_samples = 0

        for batch_idx, (input_seq, target) in enumerate(train_loader):
            input_seq, target = input_seq.to(device), target.view(-1).to(device)

            # Forward pass
            logits = model(input_seq)  # [batch, seq_len, vocab]
            logits = logits[:, -1, :]  # only the final step prediction [batch, vocab]

            loss = criterion(logits, target)

            # Backprop
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Accuracy
            preds = logits.argmax(dim=1)
            total_correct += (preds == target).sum().item()
            total_samples += target.size(0)

            epoch_train_losses.append(loss.item())

            if batch_idx % 100 == 0 or batch_idx == len(train_loader) - 1:
                print(f"Train Batch {batch_idx+1}/{len(train_loader)} | Loss: {loss.item():.4f}")

        train_loss = np.mean(epoch_train_losses)
        train_acc = total_correct / total_samples
        train_perplexity = np.exp(train_loss)

        history["train_losses"].append(train_loss)
        history["train_accs"].append(train_acc)
        history["train_perplexities"].append(train_perplexity)

        print(f"[Epoch {epoch+1}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f} | Train Perplexity: {train_perplexity:.4f}")

        # --- Validation ---
        context_results = validate_per_context(model, criterion, validation_loaders, device)
        val_loss = []
        val_acc = []
        val_perplexity = []
        for ctx, metrics in context_results.items():
            print(f"[Validation] {ctx}: Loss={metrics['loss']:.4f} | Acc={metrics['acc']:.4f} | Perplexity={metrics['perplexity']:.4f}")
            val_loss.append(metrics['loss'])
            val_acc.append(metrics['acc'])
            val_perplexity.append(metrics['perplexity'])

        val_loss = np.mean(val_loss)
        val_acc = np.mean(val_acc)
        val_perplexity = np.mean(val_perplexity)

        print(f"[Validation Summary] Val Loss: {np.mean(val_loss):.4f} | "
              f"Val Acc: {np.mean(val_acc):.4f} | Val Perplexity: {np.mean(val_perplexity):.4f}", end="\n\n")
        print("-" * 40)

        history["val_context"].append(context_results)
        history["val_losses"].append(val_loss)
        history["val_accs"].append(val_acc)
        history["val_perplexities"].append(val_perplexity)

    print("\nTraining complete")

    return history

# %%
def test_model(test_loader: DataLoader, model: nn.Module, criterion: nn.CrossEntropyLoss, device: str | T.device = "cpu"):

    model.eval()
    test_batch_losses = []
    test_correct = 0
    test_tokens = 0

    with T.no_grad():
        for input_seq, target in test_loader:
            input_seq, target = input_seq.to(device), target.view(-1).to(device)

            # Forward pass
            logits = model(input_seq)  # [batch, seq_len, vocab]
            logits = logits[:, -1, :]
            loss = criterion(logits, target)

            preds = logits.argmax(dim=1)
            test_correct += (preds == target).sum().item()
            test_tokens += target.size(0)

            test_batch_losses.append(loss.item())

    test_loss = np.mean(test_batch_losses)
    test_acc = test_correct / test_tokens
    test_perplexity = np.exp(test_loss)

    return {
        "test_loss": test_loss,
        "test_acc": test_acc,
        "test_perplexity": test_perplexity
    }

# %% [markdown]
# ### 2. Create & Train Transformer Model

# %%
VOCABULARY_SIZE = 70        # 64 cards + 4 categories + SEP + EOS
EMBEDDING_SIZE = 256        # larger embedding to capture card features
N_ATTENTION_HEADS = 8       # more heads for better multi-feature attention
N_BLOCKS = 6                # same depth as before
MAX_SEQUENCE_LENGTH = 10    # longer max sequence to accommodate multiple past trials
FF_DIMS = 1024               # larger feedforward layer for better representation
DROPOUT_PROB = 0.2        # reduce dropout slightly to retain signal in small batches

LEARNING_RATE = 3e-4
BATCH_SIZE = 64
WEIGHT_DECAY = 1e-2
WARMUP_STEPS = 400
LABEL_SMOOTHING = 0.1
MAX_EPOCHS = 100
SEEDS = [31, 42, 45, 69, 420]

# %%
# results = train_model_round_robin(
#     train_loaders, validation_loader, transformer, criterion, 
#     optimizer, max_epochs=MAX_EPOCHS, device=device
# )
results = []

for seed in SEEDS:
    print(f"\n--- Training with Seed {seed} ---")
    set_global_seed(seed)
    
    transformer = BaselineTransformer(
        VOCABULARY_SIZE, EMBEDDING_SIZE, N_ATTENTION_HEADS,
        N_BLOCKS, MAX_SEQUENCE_LENGTH, FF_DIMS, DROPOUT_PROB, device=device
    )

    criterion =  nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTHING)
    optimizer = optim.AdamW(transformer.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=WARMUP_STEPS)  

    result = train_model(
        mixed_train_loader, validation_loaders, transformer, criterion,
        optimizer, max_epochs=MAX_EPOCHS, device=device
    )

    test_results = test_model(test_loader, transformer, criterion, device)
    print(f"[Test] Loss: {test_results["test_loss"]:.4f} | Acc: {test_results["test_acc"]:.4f} | Perplexity: {test_results["test_perplexity"]:.4f}")

    results.append({**result, **test_results})
# Out:
# --- Training with Seed 31 ---
#
# Epoch 1/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 177.8588
# Train Batch 101/450 | Loss: 4.3982
# Train Batch 201/450 | Loss: 3.7271
# Train Batch 301/450 | Loss: 3.2499
# Train Batch 401/450 | Loss: 2.7428
# Train Batch 450/450 | Loss: 2.8772
# [Epoch 1] Train Loss: 5.0107 | Train Acc: 0.2366 | Train Perplexity: 150.0163
# [Validation] color: Loss=2.4450 | Acc=0.2492 | Perplexity=11.5301
# [Validation] shape: Loss=2.4417 | Acc=0.2502 | Perplexity=11.4930
# [Validation] quantity: Loss=2.4399 | Acc=0.2483 | Perplexity=11.4714
# [Validation Summary] Val Loss: 2.4422 | Val Acc: 0.2492 | Val Perplexity: 11.4982
#
# ----------------------------------------
#
# Epoch 2/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.8405
# Train Batch 101/450 | Loss: 2.7640
# Train Batch 201/450 | Loss: 2.7549
# Train Batch 301/450 | Loss: 2.4760
# Train Batch 401/450 | Loss: 2.4283
# Train Batch 450/450 | Loss: 2.5384
# [Epoch 2] Train Loss: 2.6467 | Train Acc: 0.2451 | Train Perplexity: 14.1073
# [Validation] color: Loss=2.1936 | Acc=0.2523 | Perplexity=8.9675
# [Validation] shape: Loss=2.1949 | Acc=0.2502 | Perplexity=8.9792
# [Validation] quantity: Loss=2.1922 | Acc=0.2503 | Perplexity=8.9551
# [Validation Summary] Val Loss: 2.1936 | Val Acc: 0.2509 | Val Perplexity: 8.9673
#
# ----------------------------------------
#
# Epoch 3/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3307
# Train Batch 101/450 | Loss: 2.4686
# Train Batch 201/450 | Loss: 2.3825
# Train Batch 301/450 | Loss: 2.5006
# Train Batch 401/450 | Loss: 2.3062
# Train Batch 450/450 | Loss: 2.5166
# [Epoch 3] Train Loss: 2.4184 | Train Acc: 0.2531 | Train Perplexity: 11.2277
# [Validation] color: Loss=2.1947 | Acc=0.2518 | Perplexity=8.9769
# [Validation] shape: Loss=2.1901 | Acc=0.2564 | Perplexity=8.9363
# [Validation] quantity: Loss=2.1904 | Acc=0.2507 | Perplexity=8.9385
# [Validation Summary] Val Loss: 2.1917 | Val Acc: 0.2530 | Val Perplexity: 8.9506
#
# ----------------------------------------
#
# Epoch 4/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.3664
# Train Batch 101/450 | Loss: 2.3148
# Train Batch 201/450 | Loss: 2.2777
# Train Batch 301/450 | Loss: 2.2502
# Train Batch 401/450 | Loss: 2.4078
# Train Batch 450/450 | Loss: 2.3132
# [Epoch 4] Train Loss: 2.3204 | Train Acc: 0.2479 | Train Perplexity: 10.1798
# [Validation] color: Loss=2.1224 | Acc=0.2492 | Perplexity=8.3515
# [Validation] shape: Loss=2.1205 | Acc=0.2502 | Perplexity=8.3354
# [Validation] quantity: Loss=2.1222 | Acc=0.2483 | Perplexity=8.3494
# [Validation Summary] Val Loss: 2.1217 | Val Acc: 0.2492 | Val Perplexity: 8.3454
#
# ----------------------------------------
#
# Epoch 5/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0823
# Train Batch 101/450 | Loss: 2.3105
# Train Batch 201/450 | Loss: 2.3543
# Train Batch 301/450 | Loss: 2.1523
# Train Batch 401/450 | Loss: 2.2916
# Train Batch 450/450 | Loss: 2.1367
# [Epoch 5] Train Loss: 2.2548 | Train Acc: 0.2526 | Train Perplexity: 9.5337
# [Validation] color: Loss=2.0395 | Acc=0.2528 | Perplexity=7.6867
# [Validation] shape: Loss=2.0399 | Acc=0.2497 | Perplexity=7.6898
# [Validation] quantity: Loss=2.0396 | Acc=0.2464 | Perplexity=7.6872
# [Validation Summary] Val Loss: 2.0396 | Val Acc: 0.2496 | Val Perplexity: 7.6879
#
# ----------------------------------------
#
# Epoch 6/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.2890
# Train Batch 101/450 | Loss: 2.2706
# Train Batch 201/450 | Loss: 2.1994
# Train Batch 301/450 | Loss: 2.2337
# Train Batch 401/450 | Loss: 2.0812
# Train Batch 450/450 | Loss: 2.2354
# [Epoch 6] Train Loss: 2.1850 | Train Acc: 0.2525 | Train Perplexity: 8.8910
# [Validation] color: Loss=2.1129 | Acc=0.2532 | Perplexity=8.2720
# [Validation] shape: Loss=2.1112 | Acc=0.2543 | Perplexity=8.2582
# [Validation] quantity: Loss=2.1111 | Acc=0.2521 | Perplexity=8.2572
# [Validation Summary] Val Loss: 2.1117 | Val Acc: 0.2532 | Val Perplexity: 8.2625
#
# ----------------------------------------
#
# Epoch 7/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.1242
# Train Batch 101/450 | Loss: 2.1102
# Train Batch 201/450 | Loss: 2.1776
# Train Batch 301/450 | Loss: 2.0501
# Train Batch 401/450 | Loss: 2.1079
# Train Batch 450/450 | Loss: 2.0921
# [Epoch 7] Train Loss: 2.1463 | Train Acc: 0.2541 | Train Perplexity: 8.5535
# [Validation] color: Loss=2.0020 | Acc=0.2517 | Perplexity=7.4038
# [Validation] shape: Loss=2.0025 | Acc=0.2482 | Perplexity=7.4073
# [Validation] quantity: Loss=2.0025 | Acc=0.2480 | Perplexity=7.4074
# [Validation Summary] Val Loss: 2.0023 | Val Acc: 0.2493 | Val Perplexity: 7.4062
#
# ----------------------------------------
#
# Epoch 8/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.1090
# Train Batch 101/450 | Loss: 2.2675
# Train Batch 201/450 | Loss: 2.0307
# Train Batch 301/450 | Loss: 2.1304
# Train Batch 401/450 | Loss: 2.1687
# Train Batch 450/450 | Loss: 2.0805
# [Epoch 8] Train Loss: 2.1133 | Train Acc: 0.2533 | Train Perplexity: 8.2758
# [Validation] color: Loss=2.0762 | Acc=0.2460 | Perplexity=7.9741
# [Validation] shape: Loss=2.0747 | Acc=0.2476 | Perplexity=7.9623
# [Validation] quantity: Loss=2.0721 | Acc=0.2515 | Perplexity=7.9413
# [Validation Summary] Val Loss: 2.0743 | Val Acc: 0.2484 | Val Perplexity: 7.9592
#
# ----------------------------------------
#
# Epoch 9/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0473
# Train Batch 101/450 | Loss: 2.0637
# Train Batch 201/450 | Loss: 2.0257
# Train Batch 301/450 | Loss: 2.0407
# Train Batch 401/450 | Loss: 2.0492
# Train Batch 450/450 | Loss: 2.0420
# [Epoch 9] Train Loss: 2.0839 | Train Acc: 0.2533 | Train Perplexity: 8.0353
# [Validation] color: Loss=1.9816 | Acc=0.2537 | Perplexity=7.2543
# [Validation] shape: Loss=1.9810 | Acc=0.2547 | Perplexity=7.2500
# [Validation] quantity: Loss=1.9816 | Acc=0.2518 | Perplexity=7.2544
# [Validation Summary] Val Loss: 1.9814 | Val Acc: 0.2534 | Val Perplexity: 7.2529
#
# ----------------------------------------
#
# Epoch 10/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0081
# Train Batch 101/450 | Loss: 2.1222
# Train Batch 201/450 | Loss: 2.1019
# Train Batch 301/450 | Loss: 2.0731
# Train Batch 401/450 | Loss: 2.0984
# Train Batch 450/450 | Loss: 1.9983
# [Epoch 10] Train Loss: 2.0648 | Train Acc: 0.2533 | Train Perplexity: 7.8840
# [Validation] color: Loss=2.0142 | Acc=0.2461 | Perplexity=7.4947
# [Validation] shape: Loss=2.0125 | Acc=0.2504 | Perplexity=7.4823
# [Validation] quantity: Loss=2.0113 | Acc=0.2511 | Perplexity=7.4728
# [Validation Summary] Val Loss: 2.0127 | Val Acc: 0.2492 | Val Perplexity: 7.4833
#
# ----------------------------------------
#
# Epoch 11/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0566
# Train Batch 101/450 | Loss: 1.9988
# Train Batch 201/450 | Loss: 2.0154
# Train Batch 301/450 | Loss: 2.0318
# Train Batch 401/450 | Loss: 2.0702
# Train Batch 450/450 | Loss: 2.0006
# [Epoch 11] Train Loss: 2.0484 | Train Acc: 0.2536 | Train Perplexity: 7.7556
# [Validation] color: Loss=2.0031 | Acc=0.2460 | Perplexity=7.4123
# [Validation] shape: Loss=2.0018 | Acc=0.2476 | Perplexity=7.4027
# [Validation] quantity: Loss=2.0002 | Acc=0.2515 | Perplexity=7.3904
# [Validation Summary] Val Loss: 2.0017 | Val Acc: 0.2484 | Val Perplexity: 7.4018
#
# ----------------------------------------
#
# Epoch 12/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0732
# Train Batch 101/450 | Loss: 2.0697
# Train Batch 201/450 | Loss: 2.0616
# Train Batch 301/450 | Loss: 2.0011
# Train Batch 401/450 | Loss: 2.0033
# Train Batch 450/450 | Loss: 2.0589
# [Epoch 12] Train Loss: 2.0346 | Train Acc: 0.2533 | Train Perplexity: 7.6492
# [Validation] color: Loss=1.9911 | Acc=0.2528 | Perplexity=7.3236
# [Validation] shape: Loss=1.9909 | Acc=0.2547 | Perplexity=7.3218
# [Validation] quantity: Loss=1.9927 | Acc=0.2517 | Perplexity=7.3356
# [Validation Summary] Val Loss: 1.9916 | Val Acc: 0.2531 | Val Perplexity: 7.3270
#
# ----------------------------------------
#
# Epoch 13/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0143
# Train Batch 101/450 | Loss: 1.9937
# Train Batch 201/450 | Loss: 2.0217
# Train Batch 301/450 | Loss: 2.0062
# Train Batch 401/450 | Loss: 2.0075
# Train Batch 450/450 | Loss: 1.9619
# [Epoch 13] Train Loss: 2.0252 | Train Acc: 0.2547 | Train Perplexity: 7.5773
# [Validation] color: Loss=1.9988 | Acc=0.2472 | Perplexity=7.3805
# [Validation] shape: Loss=1.9990 | Acc=0.2480 | Perplexity=7.3814
# [Validation] quantity: Loss=2.0015 | Acc=0.2442 | Perplexity=7.4003
# [Validation Summary] Val Loss: 1.9998 | Val Acc: 0.2465 | Val Perplexity: 7.3874
#
# ----------------------------------------
#
# Epoch 14/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0206
# Train Batch 101/450 | Loss: 2.0133
# Train Batch 201/450 | Loss: 2.0408
# Train Batch 301/450 | Loss: 1.9880
# Train Batch 401/450 | Loss: 2.0131
# Train Batch 450/450 | Loss: 1.9841
# [Epoch 14] Train Loss: 2.0188 | Train Acc: 0.2601 | Train Perplexity: 7.5296
# [Validation] color: Loss=1.9823 | Acc=0.2489 | Perplexity=7.2595
# [Validation] shape: Loss=1.9827 | Acc=0.2445 | Perplexity=7.2625
# [Validation] quantity: Loss=1.9840 | Acc=0.2503 | Perplexity=7.2716
# [Validation Summary] Val Loss: 1.9830 | Val Acc: 0.2479 | Val Perplexity: 7.2645
#
# ----------------------------------------
#
# Epoch 15/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9750
# Train Batch 101/450 | Loss: 2.0446
# Train Batch 201/450 | Loss: 1.9829
# Train Batch 301/450 | Loss: 2.0505
# Train Batch 401/450 | Loss: 1.9851
# Train Batch 450/450 | Loss: 1.9678
# [Epoch 15] Train Loss: 2.0048 | Train Acc: 0.2596 | Train Perplexity: 7.4248
# [Validation] color: Loss=1.9859 | Acc=0.2506 | Perplexity=7.2859
# [Validation] shape: Loss=1.9869 | Acc=0.2501 | Perplexity=7.2926
# [Validation] quantity: Loss=1.9857 | Acc=0.2493 | Perplexity=7.2841
# [Validation Summary] Val Loss: 1.9862 | Val Acc: 0.2500 | Val Perplexity: 7.2875
#
# ----------------------------------------
#
# Epoch 16/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9909
# Train Batch 101/450 | Loss: 1.9988
# Train Batch 201/450 | Loss: 2.0591
# Train Batch 301/450 | Loss: 1.9495
# Train Batch 401/450 | Loss: 1.9978
# Train Batch 450/450 | Loss: 1.9785
# [Epoch 16] Train Loss: 2.0012 | Train Acc: 0.2611 | Train Perplexity: 7.3980
# [Validation] color: Loss=1.9764 | Acc=0.2493 | Perplexity=7.2169
# [Validation] shape: Loss=1.9769 | Acc=0.2474 | Perplexity=7.2202
# [Validation] quantity: Loss=1.9774 | Acc=0.2517 | Perplexity=7.2237
# [Validation Summary] Val Loss: 1.9769 | Val Acc: 0.2494 | Val Perplexity: 7.2203
#
# ----------------------------------------
#
# Epoch 17/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9624
# Train Batch 101/450 | Loss: 1.9817
# Train Batch 201/450 | Loss: 2.0218
# Train Batch 301/450 | Loss: 2.0531
# Train Batch 401/450 | Loss: 1.9817
# Train Batch 450/450 | Loss: 1.9857
# [Epoch 17] Train Loss: 1.9956 | Train Acc: 0.2624 | Train Perplexity: 7.3568
# [Validation] color: Loss=2.0023 | Acc=0.2518 | Perplexity=7.4058
# [Validation] shape: Loss=2.0017 | Acc=0.2524 | Perplexity=7.4019
# [Validation] quantity: Loss=2.0029 | Acc=0.2539 | Perplexity=7.4103
# [Validation Summary] Val Loss: 2.0023 | Val Acc: 0.2527 | Val Perplexity: 7.4060
#
# ----------------------------------------
#
# Epoch 18/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0088
# Train Batch 101/450 | Loss: 2.0188
# Train Batch 201/450 | Loss: 2.0541
# Train Batch 301/450 | Loss: 2.0113
# Train Batch 401/450 | Loss: 1.9900
# Train Batch 450/450 | Loss: 1.9815
# [Epoch 18] Train Loss: 1.9930 | Train Acc: 0.2648 | Train Perplexity: 7.3377
# [Validation] color: Loss=1.9994 | Acc=0.2487 | Perplexity=7.3847
# [Validation] shape: Loss=1.9999 | Acc=0.2502 | Perplexity=7.3884
# [Validation] quantity: Loss=2.0003 | Acc=0.2502 | Perplexity=7.3911
# [Validation Summary] Val Loss: 1.9999 | Val Acc: 0.2497 | Val Perplexity: 7.3881
#
# ----------------------------------------
#
# Epoch 19/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9664
# Train Batch 101/450 | Loss: 1.9533
# Train Batch 201/450 | Loss: 1.9741
# Train Batch 301/450 | Loss: 1.9667
# Train Batch 401/450 | Loss: 1.9727
# Train Batch 450/450 | Loss: 1.9970
# [Epoch 19] Train Loss: 1.9905 | Train Acc: 0.2643 | Train Perplexity: 7.3191
# [Validation] color: Loss=1.9905 | Acc=0.2431 | Perplexity=7.3192
# [Validation] shape: Loss=1.9910 | Acc=0.2452 | Perplexity=7.3229
# [Validation] quantity: Loss=1.9872 | Acc=0.2517 | Perplexity=7.2948
# [Validation Summary] Val Loss: 1.9896 | Val Acc: 0.2467 | Val Perplexity: 7.3123
#
# ----------------------------------------
#
# Epoch 20/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0140
# Train Batch 101/450 | Loss: 2.0485
# Train Batch 201/450 | Loss: 1.9608
# Train Batch 301/450 | Loss: 1.9751
# Train Batch 401/450 | Loss: 1.9741
# Train Batch 450/450 | Loss: 2.0212
# [Epoch 20] Train Loss: 1.9856 | Train Acc: 0.2712 | Train Perplexity: 7.2832
# [Validation] color: Loss=1.9767 | Acc=0.2501 | Perplexity=7.2191
# [Validation] shape: Loss=1.9768 | Acc=0.2509 | Perplexity=7.2194
# [Validation] quantity: Loss=1.9753 | Acc=0.2576 | Perplexity=7.2091
# [Validation Summary] Val Loss: 1.9763 | Val Acc: 0.2529 | Val Perplexity: 7.2159
#
# ----------------------------------------
#
# Epoch 21/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9544
# Train Batch 101/450 | Loss: 2.0105
# Train Batch 201/450 | Loss: 1.9096
# Train Batch 301/450 | Loss: 1.9493
# Train Batch 401/450 | Loss: 1.9500
# Train Batch 450/450 | Loss: 1.9682
# [Epoch 21] Train Loss: 1.9807 | Train Acc: 0.2707 | Train Perplexity: 7.2476
# [Validation] color: Loss=2.0003 | Acc=0.2535 | Perplexity=7.3916
# [Validation] shape: Loss=2.0008 | Acc=0.2501 | Perplexity=7.3947
# [Validation] quantity: Loss=2.0032 | Acc=0.2478 | Perplexity=7.4129
# [Validation Summary] Val Loss: 2.0014 | Val Acc: 0.2505 | Val Perplexity: 7.3998
#
# ----------------------------------------
#
# Epoch 22/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9652
# Train Batch 101/450 | Loss: 1.9456
# Train Batch 201/450 | Loss: 2.0792
# Train Batch 301/450 | Loss: 2.0724
# Train Batch 401/450 | Loss: 1.9584
# Train Batch 450/450 | Loss: 1.9360
# [Epoch 22] Train Loss: 1.9773 | Train Acc: 0.2774 | Train Perplexity: 7.2232
# [Validation] color: Loss=1.9823 | Acc=0.2507 | Perplexity=7.2594
# [Validation] shape: Loss=1.9823 | Acc=0.2492 | Perplexity=7.2595
# [Validation] quantity: Loss=1.9811 | Acc=0.2526 | Perplexity=7.2506
# [Validation Summary] Val Loss: 1.9819 | Val Acc: 0.2508 | Val Perplexity: 7.2565
#
# ----------------------------------------
#
# Epoch 23/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 2.0070
# Train Batch 101/450 | Loss: 1.9752
# Train Batch 201/450 | Loss: 1.9446
# Train Batch 301/450 | Loss: 1.9732
# Train Batch 401/450 | Loss: 1.9633
# Train Batch 450/450 | Loss: 1.9474
# [Epoch 23] Train Loss: 1.9720 | Train Acc: 0.2814 | Train Perplexity: 7.1848
# [Validation] color: Loss=1.9912 | Acc=0.2520 | Perplexity=7.3247
# [Validation] shape: Loss=1.9911 | Acc=0.2468 | Perplexity=7.3237
# [Validation] quantity: Loss=1.9885 | Acc=0.2583 | Perplexity=7.3047
# [Validation Summary] Val Loss: 1.9903 | Val Acc: 0.2524 | Val Perplexity: 7.3177
#
# ----------------------------------------
#
# Epoch 24/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9896
# Train Batch 101/450 | Loss: 1.9307
# Train Batch 201/450 | Loss: 1.9809
# Train Batch 301/450 | Loss: 1.9523
# Train Batch 401/450 | Loss: 1.9850
# Train Batch 450/450 | Loss: 1.9317
# [Epoch 24] Train Loss: 1.9759 | Train Acc: 0.2893 | Train Perplexity: 7.2130
# [Validation] color: Loss=1.9831 | Acc=0.2583 | Perplexity=7.2656
# [Validation] shape: Loss=1.9829 | Acc=0.2505 | Perplexity=7.2638
# [Validation] quantity: Loss=1.9841 | Acc=0.2575 | Perplexity=7.2724
# [Validation Summary] Val Loss: 1.9834 | Val Acc: 0.2555 | Val Perplexity: 7.2673
#
# ----------------------------------------
#
# Epoch 25/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9694
# Train Batch 101/450 | Loss: 1.9435
# Train Batch 201/450 | Loss: 1.9668
# Train Batch 301/450 | Loss: 1.9754
# Train Batch 401/450 | Loss: 1.9265
# Train Batch 450/450 | Loss: 1.9738
# [Epoch 25] Train Loss: 1.9588 | Train Acc: 0.3003 | Train Perplexity: 7.0911
# [Validation] color: Loss=1.9998 | Acc=0.2575 | Perplexity=7.3874
# [Validation] shape: Loss=2.0009 | Acc=0.2548 | Perplexity=7.3959
# [Validation] quantity: Loss=2.0004 | Acc=0.2564 | Perplexity=7.3922
# [Validation Summary] Val Loss: 2.0004 | Val Acc: 0.2562 | Val Perplexity: 7.3918
#
# ----------------------------------------
#
# Epoch 26/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9877
# Train Batch 101/450 | Loss: 1.9449
# Train Batch 201/450 | Loss: 2.0020
# Train Batch 301/450 | Loss: 1.9875
# Train Batch 401/450 | Loss: 1.8788
# Train Batch 450/450 | Loss: 1.9980
# [Epoch 26] Train Loss: 1.9568 | Train Acc: 0.3111 | Train Perplexity: 7.0766
# [Validation] color: Loss=2.0043 | Acc=0.2624 | Perplexity=7.4210
# [Validation] shape: Loss=2.0083 | Acc=0.2526 | Perplexity=7.4508
# [Validation] quantity: Loss=2.0052 | Acc=0.2570 | Perplexity=7.4273
# [Validation Summary] Val Loss: 2.0059 | Val Acc: 0.2573 | Val Perplexity: 7.4330
#
# ----------------------------------------
#
# Epoch 27/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8710
# Train Batch 101/450 | Loss: 1.9075
# Train Batch 201/450 | Loss: 1.9331
# Train Batch 301/450 | Loss: 1.9682
# Train Batch 401/450 | Loss: 1.8949
# Train Batch 450/450 | Loss: 1.8968
# [Epoch 27] Train Loss: 1.9428 | Train Acc: 0.3290 | Train Perplexity: 6.9785
# [Validation] color: Loss=2.0050 | Acc=0.2603 | Perplexity=7.4261
# [Validation] shape: Loss=2.0012 | Acc=0.2575 | Perplexity=7.3979
# [Validation] quantity: Loss=2.0038 | Acc=0.2594 | Perplexity=7.4169
# [Validation Summary] Val Loss: 2.0033 | Val Acc: 0.2591 | Val Perplexity: 7.4136
#
# ----------------------------------------
#
# Epoch 28/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9644
# Train Batch 101/450 | Loss: 1.9477
# Train Batch 201/450 | Loss: 1.9669
# Train Batch 301/450 | Loss: 1.9361
# Train Batch 401/450 | Loss: 1.9180
# Train Batch 450/450 | Loss: 1.9782
# [Epoch 28] Train Loss: 1.9378 | Train Acc: 0.3372 | Train Perplexity: 6.9436
# [Validation] color: Loss=2.0077 | Acc=0.2677 | Perplexity=7.4461
# [Validation] shape: Loss=2.0026 | Acc=0.2764 | Perplexity=7.4084
# [Validation] quantity: Loss=2.0078 | Acc=0.2687 | Perplexity=7.4472
# [Validation Summary] Val Loss: 2.0060 | Val Acc: 0.2709 | Val Perplexity: 7.4339
#
# ----------------------------------------
#
# Epoch 29/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8779
# Train Batch 101/450 | Loss: 1.9627
# Train Batch 201/450 | Loss: 1.9567
# Train Batch 301/450 | Loss: 1.9598
# Train Batch 401/450 | Loss: 1.9448
# Train Batch 450/450 | Loss: 1.9379
# [Epoch 29] Train Loss: 1.9206 | Train Acc: 0.3565 | Train Perplexity: 6.8250
# [Validation] color: Loss=2.0049 | Acc=0.2848 | Perplexity=7.4256
# [Validation] shape: Loss=1.9983 | Acc=0.2816 | Perplexity=7.3768
# [Validation] quantity: Loss=2.0169 | Acc=0.2740 | Perplexity=7.5152
# [Validation Summary] Val Loss: 2.0067 | Val Acc: 0.2801 | Val Perplexity: 7.4392
#
# ----------------------------------------
#
# Epoch 30/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8890
# Train Batch 101/450 | Loss: 1.9085
# Train Batch 201/450 | Loss: 1.9348
# Train Batch 301/450 | Loss: 1.8664
# Train Batch 401/450 | Loss: 1.9279
# Train Batch 450/450 | Loss: 1.8488
# [Epoch 30] Train Loss: 1.9047 | Train Acc: 0.3693 | Train Perplexity: 6.7171
# [Validation] color: Loss=2.0015 | Acc=0.2948 | Perplexity=7.4000
# [Validation] shape: Loss=1.9965 | Acc=0.2975 | Perplexity=7.3631
# [Validation] quantity: Loss=2.0152 | Acc=0.2853 | Perplexity=7.5021
# [Validation Summary] Val Loss: 2.0044 | Val Acc: 0.2925 | Val Perplexity: 7.4217
#
# ----------------------------------------
#
# Epoch 31/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.9045
# Train Batch 101/450 | Loss: 1.8645
# Train Batch 201/450 | Loss: 1.8149
# Train Batch 301/450 | Loss: 1.8871
# Train Batch 401/450 | Loss: 1.8265
# Train Batch 450/450 | Loss: 1.9547
# [Epoch 31] Train Loss: 1.8831 | Train Acc: 0.3873 | Train Perplexity: 6.5738
# [Validation] color: Loss=2.0162 | Acc=0.2988 | Perplexity=7.5096
# [Validation] shape: Loss=2.0170 | Acc=0.2974 | Perplexity=7.5156
# [Validation] quantity: Loss=2.0478 | Acc=0.2856 | Perplexity=7.7509
# [Validation Summary] Val Loss: 2.0270 | Val Acc: 0.2939 | Val Perplexity: 7.5920
#
# ----------------------------------------
#
# Epoch 32/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8296
# Train Batch 101/450 | Loss: 1.9726
# Train Batch 201/450 | Loss: 1.8849
# Train Batch 301/450 | Loss: 1.9206
# Train Batch 401/450 | Loss: 1.7937
# Train Batch 450/450 | Loss: 1.8785
# [Epoch 32] Train Loss: 1.8677 | Train Acc: 0.3997 | Train Perplexity: 6.4732
# [Validation] color: Loss=2.0243 | Acc=0.3274 | Perplexity=7.5706
# [Validation] shape: Loss=2.0274 | Acc=0.3167 | Perplexity=7.5945
# [Validation] quantity: Loss=2.0632 | Acc=0.3023 | Perplexity=7.8714
# [Validation Summary] Val Loss: 2.0383 | Val Acc: 0.3155 | Val Perplexity: 7.6789
#
# ----------------------------------------
#
# Epoch 33/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8111
# Train Batch 101/450 | Loss: 1.7536
# Train Batch 201/450 | Loss: 1.8669
# Train Batch 301/450 | Loss: 1.9573
# Train Batch 401/450 | Loss: 1.8869
# Train Batch 450/450 | Loss: 1.8213
# [Epoch 33] Train Loss: 1.8422 | Train Acc: 0.4209 | Train Perplexity: 6.3107
# [Validation] color: Loss=1.9906 | Acc=0.3366 | Perplexity=7.3199
# [Validation] shape: Loss=1.9962 | Acc=0.3250 | Perplexity=7.3612
# [Validation] quantity: Loss=2.0383 | Acc=0.3063 | Perplexity=7.6774
# [Validation Summary] Val Loss: 2.0084 | Val Acc: 0.3226 | Val Perplexity: 7.4528
#
# ----------------------------------------
#
# Epoch 34/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8066
# Train Batch 101/450 | Loss: 1.8134
# Train Batch 201/450 | Loss: 1.8012
# Train Batch 301/450 | Loss: 1.8631
# Train Batch 401/450 | Loss: 1.7397
# Train Batch 450/450 | Loss: 1.8142
# [Epoch 34] Train Loss: 1.8245 | Train Acc: 0.4367 | Train Perplexity: 6.1997
# [Validation] color: Loss=1.9675 | Acc=0.3377 | Perplexity=7.1529
# [Validation] shape: Loss=1.9688 | Acc=0.3351 | Perplexity=7.1618
# [Validation] quantity: Loss=2.0097 | Acc=0.3085 | Perplexity=7.4610
# [Validation Summary] Val Loss: 1.9820 | Val Acc: 0.3271 | Val Perplexity: 7.2586
#
# ----------------------------------------
#
# Epoch 35/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8028
# Train Batch 101/450 | Loss: 1.7824
# Train Batch 201/450 | Loss: 1.7674
# Train Batch 301/450 | Loss: 1.8759
# Train Batch 401/450 | Loss: 1.8797
# Train Batch 450/450 | Loss: 1.8530
# [Epoch 35] Train Loss: 1.8064 | Train Acc: 0.4497 | Train Perplexity: 6.0888
# [Validation] color: Loss=1.9613 | Acc=0.3638 | Perplexity=7.1089
# [Validation] shape: Loss=1.9830 | Acc=0.3488 | Perplexity=7.2646
# [Validation] quantity: Loss=2.0434 | Acc=0.3167 | Perplexity=7.7168
# [Validation Summary] Val Loss: 1.9959 | Val Acc: 0.3431 | Val Perplexity: 7.3634
#
# ----------------------------------------
#
# Epoch 36/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.7570
# Train Batch 101/450 | Loss: 1.8098
# Train Batch 201/450 | Loss: 1.8026
# Train Batch 301/450 | Loss: 1.7627
# Train Batch 401/450 | Loss: 1.8271
# Train Batch 450/450 | Loss: 1.7739
# [Epoch 36] Train Loss: 1.7787 | Train Acc: 0.4703 | Train Perplexity: 5.9219
# [Validation] color: Loss=1.9432 | Acc=0.3870 | Perplexity=6.9808
# [Validation] shape: Loss=1.9681 | Acc=0.3632 | Perplexity=7.1574
# [Validation] quantity: Loss=2.0680 | Acc=0.3256 | Perplexity=7.9093
# [Validation Summary] Val Loss: 1.9931 | Val Acc: 0.3586 | Val Perplexity: 7.3492
#
# ----------------------------------------
#
# Epoch 37/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.7427
# Train Batch 101/450 | Loss: 1.6822
# Train Batch 201/450 | Loss: 1.8023
# Train Batch 301/450 | Loss: 1.8402
# Train Batch 401/450 | Loss: 1.8464
# Train Batch 450/450 | Loss: 1.7552
# [Epoch 37] Train Loss: 1.7563 | Train Acc: 0.4824 | Train Perplexity: 5.7910
# [Validation] color: Loss=1.9148 | Acc=0.4032 | Perplexity=6.7857
# [Validation] shape: Loss=1.9406 | Acc=0.3877 | Perplexity=6.9631
# [Validation] quantity: Loss=2.0454 | Acc=0.3423 | Perplexity=7.7320
# [Validation Summary] Val Loss: 1.9669 | Val Acc: 0.3777 | Val Perplexity: 7.1603
#
# ----------------------------------------
#
# Epoch 38/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6370
# Train Batch 101/450 | Loss: 1.6971
# Train Batch 201/450 | Loss: 1.7154
# Train Batch 301/450 | Loss: 1.8069
# Train Batch 401/450 | Loss: 1.6459
# Train Batch 450/450 | Loss: 1.8378
# [Epoch 38] Train Loss: 1.7363 | Train Acc: 0.4984 | Train Perplexity: 5.6762
# [Validation] color: Loss=1.8889 | Acc=0.4155 | Perplexity=6.6119
# [Validation] shape: Loss=1.9311 | Acc=0.3927 | Perplexity=6.8970
# [Validation] quantity: Loss=2.0597 | Acc=0.3344 | Perplexity=7.8433
# [Validation Summary] Val Loss: 1.9599 | Val Acc: 0.3809 | Val Perplexity: 7.1174
#
# ----------------------------------------
#
# Epoch 39/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.8246
# Train Batch 101/450 | Loss: 1.8659
# Train Batch 201/450 | Loss: 1.6978
# Train Batch 301/450 | Loss: 1.6994
# Train Batch 401/450 | Loss: 1.6815
# Train Batch 450/450 | Loss: 1.6681
# [Epoch 39] Train Loss: 1.7157 | Train Acc: 0.5137 | Train Perplexity: 5.5608
# [Validation] color: Loss=1.8322 | Acc=0.4442 | Perplexity=6.2476
# [Validation] shape: Loss=1.8957 | Acc=0.4104 | Perplexity=6.6575
# [Validation] quantity: Loss=2.0451 | Acc=0.3451 | Perplexity=7.7302
# [Validation Summary] Val Loss: 1.9244 | Val Acc: 0.3999 | Val Perplexity: 6.8784
#
# ----------------------------------------
#
# Epoch 40/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.7451
# Train Batch 101/450 | Loss: 1.6431
# Train Batch 201/450 | Loss: 1.6312
# Train Batch 301/450 | Loss: 1.6975
# Train Batch 401/450 | Loss: 1.6360
# Train Batch 450/450 | Loss: 1.7787
# [Epoch 40] Train Loss: 1.6925 | Train Acc: 0.5317 | Train Perplexity: 5.4332
# [Validation] color: Loss=1.8152 | Acc=0.4752 | Perplexity=6.1420
# [Validation] shape: Loss=1.9018 | Acc=0.4255 | Perplexity=6.6981
# [Validation] quantity: Loss=2.0865 | Acc=0.3554 | Perplexity=8.0565
# [Validation Summary] Val Loss: 1.9345 | Val Acc: 0.4187 | Val Perplexity: 6.9655
#
# ----------------------------------------
#
# Epoch 41/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6971
# Train Batch 101/450 | Loss: 1.5949
# Train Batch 201/450 | Loss: 1.6971
# Train Batch 301/450 | Loss: 1.5435
# Train Batch 401/450 | Loss: 1.6549
# Train Batch 450/450 | Loss: 1.7160
# [Epoch 41] Train Loss: 1.6684 | Train Acc: 0.5426 | Train Perplexity: 5.3035
# [Validation] color: Loss=1.7712 | Acc=0.5075 | Perplexity=5.8780
# [Validation] shape: Loss=1.8806 | Acc=0.4569 | Perplexity=6.5575
# [Validation] quantity: Loss=2.1117 | Acc=0.3566 | Perplexity=8.2622
# [Validation Summary] Val Loss: 1.9212 | Val Acc: 0.4403 | Val Perplexity: 6.8992
#
# ----------------------------------------
#
# Epoch 42/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6017
# Train Batch 101/450 | Loss: 1.6545
# Train Batch 201/450 | Loss: 1.6449
# Train Batch 301/450 | Loss: 1.8206
# Train Batch 401/450 | Loss: 1.5576
# Train Batch 450/450 | Loss: 1.4646
# [Epoch 42] Train Loss: 1.6482 | Train Acc: 0.5593 | Train Perplexity: 5.1975
# [Validation] color: Loss=1.7283 | Acc=0.5294 | Perplexity=5.6311
# [Validation] shape: Loss=1.8425 | Acc=0.4733 | Perplexity=6.3123
# [Validation] quantity: Loss=2.0916 | Acc=0.3600 | Perplexity=8.0975
# [Validation Summary] Val Loss: 1.8875 | Val Acc: 0.4542 | Val Perplexity: 6.6803
#
# ----------------------------------------
#
# Epoch 43/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6416
# Train Batch 101/450 | Loss: 1.6349
# Train Batch 201/450 | Loss: 1.7074
# Train Batch 301/450 | Loss: 1.4242
# Train Batch 401/450 | Loss: 1.5655
# Train Batch 450/450 | Loss: 1.4911
# [Epoch 43] Train Loss: 1.6198 | Train Acc: 0.5789 | Train Perplexity: 5.0523
# [Validation] color: Loss=1.7044 | Acc=0.5529 | Perplexity=5.4980
# [Validation] shape: Loss=1.8280 | Acc=0.4851 | Perplexity=6.2213
# [Validation] quantity: Loss=2.1136 | Acc=0.3626 | Perplexity=8.2784
# [Validation Summary] Val Loss: 1.8820 | Val Acc: 0.4669 | Val Perplexity: 6.6659
#
# ----------------------------------------
#
# Epoch 44/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6337
# Train Batch 101/450 | Loss: 1.3703
# Train Batch 201/450 | Loss: 1.7311
# Train Batch 301/450 | Loss: 1.5680
# Train Batch 401/450 | Loss: 1.6503
# Train Batch 450/450 | Loss: 1.6212
# [Epoch 44] Train Loss: 1.6077 | Train Acc: 0.5892 | Train Perplexity: 4.9914
# [Validation] color: Loss=1.6856 | Acc=0.5554 | Perplexity=5.3956
# [Validation] shape: Loss=1.8158 | Acc=0.4843 | Perplexity=6.1459
# [Validation] quantity: Loss=2.1056 | Acc=0.3635 | Perplexity=8.2121
# [Validation Summary] Val Loss: 1.8690 | Val Acc: 0.4677 | Val Perplexity: 6.5845
#
# ----------------------------------------
#
# Epoch 45/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5126
# Train Batch 101/450 | Loss: 1.3882
# Train Batch 201/450 | Loss: 1.5130
# Train Batch 301/450 | Loss: 1.6122
# Train Batch 401/450 | Loss: 1.5951
# Train Batch 450/450 | Loss: 1.5788
# [Epoch 45] Train Loss: 1.5855 | Train Acc: 0.6019 | Train Perplexity: 4.8816
# [Validation] color: Loss=1.6642 | Acc=0.5777 | Perplexity=5.2814
# [Validation] shape: Loss=1.8201 | Acc=0.5058 | Perplexity=6.1727
# [Validation] quantity: Loss=2.1362 | Acc=0.3692 | Perplexity=8.4673
# [Validation Summary] Val Loss: 1.8735 | Val Acc: 0.4842 | Val Perplexity: 6.6405
#
# ----------------------------------------
#
# Epoch 46/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5326
# Train Batch 101/450 | Loss: 1.4863
# Train Batch 201/450 | Loss: 1.4873
# Train Batch 301/450 | Loss: 1.5857
# Train Batch 401/450 | Loss: 1.6706
# Train Batch 450/450 | Loss: 1.5435
# [Epoch 46] Train Loss: 1.5749 | Train Acc: 0.6089 | Train Perplexity: 4.8302
# [Validation] color: Loss=1.6415 | Acc=0.5947 | Perplexity=5.1628
# [Validation] shape: Loss=1.8175 | Acc=0.5093 | Perplexity=6.1562
# [Validation] quantity: Loss=2.1499 | Acc=0.3698 | Perplexity=8.5838
# [Validation Summary] Val Loss: 1.8696 | Val Acc: 0.4913 | Val Perplexity: 6.6343
#
# ----------------------------------------
#
# Epoch 47/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5748
# Train Batch 101/450 | Loss: 1.5472
# Train Batch 201/450 | Loss: 1.5173
# Train Batch 301/450 | Loss: 1.5116
# Train Batch 401/450 | Loss: 1.5518
# Train Batch 450/450 | Loss: 1.5944
# [Epoch 47] Train Loss: 1.5595 | Train Acc: 0.6193 | Train Perplexity: 4.7562
# [Validation] color: Loss=1.6491 | Acc=0.5982 | Perplexity=5.2023
# [Validation] shape: Loss=1.7864 | Acc=0.5319 | Perplexity=5.9680
# [Validation] quantity: Loss=2.1367 | Acc=0.3757 | Perplexity=8.4716
# [Validation Summary] Val Loss: 1.8574 | Val Acc: 0.5019 | Val Perplexity: 6.5473
#
# ----------------------------------------
#
# Epoch 48/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6629
# Train Batch 101/450 | Loss: 1.5501
# Train Batch 201/450 | Loss: 1.3457
# Train Batch 301/450 | Loss: 1.6205
# Train Batch 401/450 | Loss: 1.4983
# Train Batch 450/450 | Loss: 1.5446
# [Epoch 48] Train Loss: 1.5463 | Train Acc: 0.6264 | Train Perplexity: 4.6942
# [Validation] color: Loss=1.6443 | Acc=0.5942 | Perplexity=5.1774
# [Validation] shape: Loss=1.8173 | Acc=0.5188 | Perplexity=6.1553
# [Validation] quantity: Loss=2.1765 | Acc=0.3736 | Perplexity=8.8156
# [Validation Summary] Val Loss: 1.8794 | Val Acc: 0.4955 | Val Perplexity: 6.7161
#
# ----------------------------------------
#
# Epoch 49/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3815
# Train Batch 101/450 | Loss: 1.6612
# Train Batch 201/450 | Loss: 1.4670
# Train Batch 301/450 | Loss: 1.4007
# Train Batch 401/450 | Loss: 1.7552
# Train Batch 450/450 | Loss: 1.5577
# [Epoch 49] Train Loss: 1.5306 | Train Acc: 0.6362 | Train Perplexity: 4.6207
# [Validation] color: Loss=1.6317 | Acc=0.6104 | Perplexity=5.1127
# [Validation] shape: Loss=1.8076 | Acc=0.5331 | Perplexity=6.0958
# [Validation] quantity: Loss=2.1818 | Acc=0.3804 | Perplexity=8.8624
# [Validation Summary] Val Loss: 1.8737 | Val Acc: 0.5080 | Val Perplexity: 6.6903
#
# ----------------------------------------
#
# Epoch 50/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.6238
# Train Batch 101/450 | Loss: 1.4374
# Train Batch 201/450 | Loss: 1.5744
# Train Batch 301/450 | Loss: 1.4985
# Train Batch 401/450 | Loss: 1.6271
# Train Batch 450/450 | Loss: 1.4695
# [Epoch 50] Train Loss: 1.5182 | Train Acc: 0.6426 | Train Perplexity: 4.5638
# [Validation] color: Loss=1.6334 | Acc=0.6150 | Perplexity=5.1214
# [Validation] shape: Loss=1.8020 | Acc=0.5390 | Perplexity=6.0618
# [Validation] quantity: Loss=2.1767 | Acc=0.3785 | Perplexity=8.8172
# [Validation Summary] Val Loss: 1.8707 | Val Acc: 0.5108 | Val Perplexity: 6.6668
#
# ----------------------------------------
#
# Epoch 51/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5328
# Train Batch 101/450 | Loss: 1.5164
# Train Batch 201/450 | Loss: 1.5402
# Train Batch 301/450 | Loss: 1.4792
# Train Batch 401/450 | Loss: 1.6108
# Train Batch 450/450 | Loss: 1.4631
# [Epoch 51] Train Loss: 1.4971 | Train Acc: 0.6539 | Train Perplexity: 4.4685
# [Validation] color: Loss=1.6305 | Acc=0.6222 | Perplexity=5.1066
# [Validation] shape: Loss=1.8095 | Acc=0.5398 | Perplexity=6.1077
# [Validation] quantity: Loss=2.2495 | Acc=0.3770 | Perplexity=9.4832
# [Validation Summary] Val Loss: 1.8965 | Val Acc: 0.5130 | Val Perplexity: 6.8992
#
# ----------------------------------------
#
# Epoch 52/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.4235
# Train Batch 101/450 | Loss: 1.4196
# Train Batch 201/450 | Loss: 1.5286
# Train Batch 301/450 | Loss: 1.5643
# Train Batch 401/450 | Loss: 1.6114
# Train Batch 450/450 | Loss: 1.5152
# [Epoch 52] Train Loss: 1.4940 | Train Acc: 0.6562 | Train Perplexity: 4.4547
# [Validation] color: Loss=1.6480 | Acc=0.6047 | Perplexity=5.1967
# [Validation] shape: Loss=1.8292 | Acc=0.5267 | Perplexity=6.2292
# [Validation] quantity: Loss=2.2099 | Acc=0.3732 | Perplexity=9.1147
# [Validation Summary] Val Loss: 1.8957 | Val Acc: 0.5015 | Val Perplexity: 6.8469
#
# ----------------------------------------
#
# Epoch 53/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5428
# Train Batch 101/450 | Loss: 1.4541
# Train Batch 201/450 | Loss: 1.4129
# Train Batch 301/450 | Loss: 1.3656
# Train Batch 401/450 | Loss: 1.3701
# Train Batch 450/450 | Loss: 1.5199
# [Epoch 53] Train Loss: 1.4756 | Train Acc: 0.6651 | Train Perplexity: 4.3736
# [Validation] color: Loss=1.6727 | Acc=0.6006 | Perplexity=5.3263
# [Validation] shape: Loss=1.7972 | Acc=0.5498 | Perplexity=6.0326
# [Validation] quantity: Loss=2.2279 | Acc=0.3865 | Perplexity=9.2800
# [Validation Summary] Val Loss: 1.8992 | Val Acc: 0.5123 | Val Perplexity: 6.8796
#
# ----------------------------------------
#
# Epoch 54/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5552
# Train Batch 101/450 | Loss: 1.5620
# Train Batch 201/450 | Loss: 1.5490
# Train Batch 301/450 | Loss: 1.5199
# Train Batch 401/450 | Loss: 1.5665
# Train Batch 450/450 | Loss: 1.5189
# [Epoch 54] Train Loss: 1.4692 | Train Acc: 0.6652 | Train Perplexity: 4.3456
# [Validation] color: Loss=1.6181 | Acc=0.6255 | Perplexity=5.0435
# [Validation] shape: Loss=1.7989 | Acc=0.5448 | Perplexity=6.0433
# [Validation] quantity: Loss=2.2407 | Acc=0.3805 | Perplexity=9.3998
# [Validation Summary] Val Loss: 1.8859 | Val Acc: 0.5169 | Val Perplexity: 6.8288
#
# ----------------------------------------
#
# Epoch 55/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3392
# Train Batch 101/450 | Loss: 1.3615
# Train Batch 201/450 | Loss: 1.5426
# Train Batch 301/450 | Loss: 1.5865
# Train Batch 401/450 | Loss: 1.5919
# Train Batch 450/450 | Loss: 1.3739
# [Epoch 55] Train Loss: 1.4601 | Train Acc: 0.6706 | Train Perplexity: 4.3063
# [Validation] color: Loss=1.6230 | Acc=0.6162 | Perplexity=5.0682
# [Validation] shape: Loss=1.7941 | Acc=0.5425 | Perplexity=6.0139
# [Validation] quantity: Loss=2.1938 | Acc=0.3908 | Perplexity=8.9693
# [Validation Summary] Val Loss: 1.8703 | Val Acc: 0.5165 | Val Perplexity: 6.6838
#
# ----------------------------------------
#
# Epoch 56/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5193
# Train Batch 101/450 | Loss: 1.5226
# Train Batch 201/450 | Loss: 1.4771
# Train Batch 301/450 | Loss: 1.4414
# Train Batch 401/450 | Loss: 1.4550
# Train Batch 450/450 | Loss: 1.3941
# [Epoch 56] Train Loss: 1.4448 | Train Acc: 0.6800 | Train Perplexity: 4.2409
# [Validation] color: Loss=1.6589 | Acc=0.6119 | Perplexity=5.2534
# [Validation] shape: Loss=1.8542 | Acc=0.5312 | Perplexity=6.3866
# [Validation] quantity: Loss=2.2493 | Acc=0.3825 | Perplexity=9.4814
# [Validation Summary] Val Loss: 1.9208 | Val Acc: 0.5085 | Val Perplexity: 7.0405
#
# ----------------------------------------
#
# Epoch 57/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3917
# Train Batch 101/450 | Loss: 1.4245
# Train Batch 201/450 | Loss: 1.4349
# Train Batch 301/450 | Loss: 1.5240
# Train Batch 401/450 | Loss: 1.4965
# Train Batch 450/450 | Loss: 1.3158
# [Epoch 57] Train Loss: 1.4412 | Train Acc: 0.6839 | Train Perplexity: 4.2258
# [Validation] color: Loss=1.6500 | Acc=0.6198 | Perplexity=5.2068
# [Validation] shape: Loss=1.8072 | Acc=0.5515 | Perplexity=6.0931
# [Validation] quantity: Loss=2.2418 | Acc=0.3931 | Perplexity=9.4099
# [Validation Summary] Val Loss: 1.8996 | Val Acc: 0.5215 | Val Perplexity: 6.9033
#
# ----------------------------------------
#
# Epoch 58/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3048
# Train Batch 101/450 | Loss: 1.4265
# Train Batch 201/450 | Loss: 1.5128
# Train Batch 301/450 | Loss: 1.4052
# Train Batch 401/450 | Loss: 1.4843
# Train Batch 450/450 | Loss: 1.4457
# [Epoch 58] Train Loss: 1.4254 | Train Acc: 0.6907 | Train Perplexity: 4.1596
# [Validation] color: Loss=1.6834 | Acc=0.6032 | Perplexity=5.3841
# [Validation] shape: Loss=1.8346 | Acc=0.5468 | Perplexity=6.2629
# [Validation] quantity: Loss=2.2639 | Acc=0.3989 | Perplexity=9.6207
# [Validation Summary] Val Loss: 1.9273 | Val Acc: 0.5163 | Val Perplexity: 7.0892
#
# ----------------------------------------
#
# Epoch 59/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.4172
# Train Batch 101/450 | Loss: 1.4199
# Train Batch 201/450 | Loss: 1.4417
# Train Batch 301/450 | Loss: 1.4362
# Train Batch 401/450 | Loss: 1.5242
# Train Batch 450/450 | Loss: 1.4735
# [Epoch 59] Train Loss: 1.4175 | Train Acc: 0.6894 | Train Perplexity: 4.1266
# [Validation] color: Loss=1.6935 | Acc=0.5958 | Perplexity=5.4385
# [Validation] shape: Loss=1.8188 | Acc=0.5499 | Perplexity=6.1642
# [Validation] quantity: Loss=2.2547 | Acc=0.3943 | Perplexity=9.5327
# [Validation Summary] Val Loss: 1.9223 | Val Acc: 0.5133 | Val Perplexity: 7.0451
#
# ----------------------------------------
#
# Epoch 60/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3848
# Train Batch 101/450 | Loss: 1.1915
# Train Batch 201/450 | Loss: 1.4233
# Train Batch 301/450 | Loss: 1.2163
# Train Batch 401/450 | Loss: 1.3907
# Train Batch 450/450 | Loss: 1.3105
# [Epoch 60] Train Loss: 1.4092 | Train Acc: 0.6976 | Train Perplexity: 4.0925
# [Validation] color: Loss=1.6758 | Acc=0.6045 | Perplexity=5.3428
# [Validation] shape: Loss=1.8182 | Acc=0.5494 | Perplexity=6.1606
# [Validation] quantity: Loss=2.2521 | Acc=0.3925 | Perplexity=9.5078
# [Validation Summary] Val Loss: 1.9153 | Val Acc: 0.5155 | Val Perplexity: 7.0037
#
# ----------------------------------------
#
# Epoch 61/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.1930
# Train Batch 101/450 | Loss: 1.3395
# Train Batch 201/450 | Loss: 1.2730
# Train Batch 301/450 | Loss: 1.3568
# Train Batch 401/450 | Loss: 1.3196
# Train Batch 450/450 | Loss: 1.5011
# [Epoch 61] Train Loss: 1.4014 | Train Acc: 0.6983 | Train Perplexity: 4.0607
# [Validation] color: Loss=1.6762 | Acc=0.6091 | Perplexity=5.3452
# [Validation] shape: Loss=1.8470 | Acc=0.5360 | Perplexity=6.3409
# [Validation] quantity: Loss=2.2759 | Acc=0.3922 | Perplexity=9.7366
# [Validation Summary] Val Loss: 1.9330 | Val Acc: 0.5124 | Val Perplexity: 7.1409
#
# ----------------------------------------
#
# Epoch 62/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.2266
# Train Batch 101/450 | Loss: 1.4697
# Train Batch 201/450 | Loss: 1.3609
# Train Batch 301/450 | Loss: 1.5448
# Train Batch 401/450 | Loss: 1.3939
# Train Batch 450/450 | Loss: 1.5225
# [Epoch 62] Train Loss: 1.3811 | Train Acc: 0.7112 | Train Perplexity: 3.9793
# [Validation] color: Loss=1.7130 | Acc=0.5989 | Perplexity=5.5458
# [Validation] shape: Loss=1.8750 | Acc=0.5394 | Perplexity=6.5210
# [Validation] quantity: Loss=2.3354 | Acc=0.3894 | Perplexity=10.3334
# [Validation Summary] Val Loss: 1.9745 | Val Acc: 0.5092 | Val Perplexity: 7.4668
#
# ----------------------------------------
#
# Epoch 63/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.2330
# Train Batch 101/450 | Loss: 1.3271
# Train Batch 201/450 | Loss: 1.6218
# Train Batch 301/450 | Loss: 1.4500
# Train Batch 401/450 | Loss: 1.2258
# Train Batch 450/450 | Loss: 1.2870
# [Epoch 63] Train Loss: 1.3728 | Train Acc: 0.7167 | Train Perplexity: 3.9462
# [Validation] color: Loss=1.6955 | Acc=0.6006 | Perplexity=5.4493
# [Validation] shape: Loss=1.8201 | Acc=0.5428 | Perplexity=6.1726
# [Validation] quantity: Loss=2.2611 | Acc=0.3923 | Perplexity=9.5935
# [Validation Summary] Val Loss: 1.9256 | Val Acc: 0.5119 | Val Perplexity: 7.0718
#
# ----------------------------------------
#
# Epoch 64/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3272
# Train Batch 101/450 | Loss: 1.4116
# Train Batch 201/450 | Loss: 1.4872
# Train Batch 301/450 | Loss: 1.4436
# Train Batch 401/450 | Loss: 1.3449
# Train Batch 450/450 | Loss: 1.3211
# [Epoch 64] Train Loss: 1.3686 | Train Acc: 0.7170 | Train Perplexity: 3.9297
# [Validation] color: Loss=1.7308 | Acc=0.5861 | Perplexity=5.6450
# [Validation] shape: Loss=1.8568 | Acc=0.5407 | Perplexity=6.4030
# [Validation] quantity: Loss=2.3034 | Acc=0.4010 | Perplexity=10.0086
# [Validation Summary] Val Loss: 1.9637 | Val Acc: 0.5093 | Val Perplexity: 7.3522
#
# ----------------------------------------
#
# Epoch 65/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5277
# Train Batch 101/450 | Loss: 1.4499
# Train Batch 201/450 | Loss: 1.3424
# Train Batch 301/450 | Loss: 1.4645
# Train Batch 401/450 | Loss: 1.3930
# Train Batch 450/450 | Loss: 1.3534
# [Epoch 65] Train Loss: 1.3519 | Train Acc: 0.7260 | Train Perplexity: 3.8648
# [Validation] color: Loss=1.7426 | Acc=0.5962 | Perplexity=5.7124
# [Validation] shape: Loss=1.8844 | Acc=0.5436 | Perplexity=6.5824
# [Validation] quantity: Loss=2.3367 | Acc=0.3921 | Perplexity=10.3467
# [Validation Summary] Val Loss: 1.9879 | Val Acc: 0.5107 | Val Perplexity: 7.5471
#
# ----------------------------------------
#
# Epoch 66/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3423
# Train Batch 101/450 | Loss: 1.3009
# Train Batch 201/450 | Loss: 1.3628
# Train Batch 301/450 | Loss: 1.3873
# Train Batch 401/450 | Loss: 1.3638
# Train Batch 450/450 | Loss: 1.3984
# [Epoch 66] Train Loss: 1.3460 | Train Acc: 0.7269 | Train Perplexity: 3.8418
# [Validation] color: Loss=1.7229 | Acc=0.6033 | Perplexity=5.6008
# [Validation] shape: Loss=1.8798 | Acc=0.5369 | Perplexity=6.5521
# [Validation] quantity: Loss=2.3536 | Acc=0.3840 | Perplexity=10.5236
# [Validation Summary] Val Loss: 1.9854 | Val Acc: 0.5081 | Val Perplexity: 7.5588
#
# ----------------------------------------
#
# Epoch 67/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3599
# Train Batch 101/450 | Loss: 1.3286
# Train Batch 201/450 | Loss: 1.3134
# Train Batch 301/450 | Loss: 1.2811
# Train Batch 401/450 | Loss: 1.3731
# Train Batch 450/450 | Loss: 1.3077
# [Epoch 67] Train Loss: 1.3386 | Train Acc: 0.7332 | Train Perplexity: 3.8136
# [Validation] color: Loss=1.7584 | Acc=0.5868 | Perplexity=5.8029
# [Validation] shape: Loss=1.8815 | Acc=0.5351 | Perplexity=6.5631
# [Validation] quantity: Loss=2.3634 | Acc=0.3860 | Perplexity=10.6269
# [Validation Summary] Val Loss: 2.0011 | Val Acc: 0.5026 | Val Perplexity: 7.6643
#
# ----------------------------------------
#
# Epoch 68/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.1981
# Train Batch 101/450 | Loss: 1.2376
# Train Batch 201/450 | Loss: 1.3939
# Train Batch 301/450 | Loss: 1.4515
# Train Batch 401/450 | Loss: 1.2817
# Train Batch 450/450 | Loss: 1.2912
# [Epoch 68] Train Loss: 1.3337 | Train Acc: 0.7332 | Train Perplexity: 3.7949
# [Validation] color: Loss=1.7305 | Acc=0.5998 | Perplexity=5.6432
# [Validation] shape: Loss=1.8570 | Acc=0.5510 | Perplexity=6.4044
# [Validation] quantity: Loss=2.3372 | Acc=0.3958 | Perplexity=10.3527
# [Validation Summary] Val Loss: 1.9749 | Val Acc: 0.5156 | Val Perplexity: 7.4668
#
# ----------------------------------------
#
# Epoch 69/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3094
# Train Batch 101/450 | Loss: 1.2783
# Train Batch 201/450 | Loss: 1.4012
# Train Batch 301/450 | Loss: 1.3610
# Train Batch 401/450 | Loss: 1.3099
# Train Batch 450/450 | Loss: 1.1505
# [Epoch 69] Train Loss: 1.3215 | Train Acc: 0.7421 | Train Perplexity: 3.7490
# [Validation] color: Loss=1.7409 | Acc=0.5956 | Perplexity=5.7022
# [Validation] shape: Loss=1.8903 | Acc=0.5393 | Perplexity=6.6211
# [Validation] quantity: Loss=2.3371 | Acc=0.3958 | Perplexity=10.3515
# [Validation Summary] Val Loss: 1.9894 | Val Acc: 0.5102 | Val Perplexity: 7.5583
#
# ----------------------------------------
#
# Epoch 70/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3129
# Train Batch 101/450 | Loss: 1.1290
# Train Batch 201/450 | Loss: 1.2578
# Train Batch 301/450 | Loss: 1.2521
# Train Batch 401/450 | Loss: 1.3216
# Train Batch 450/450 | Loss: 1.2499
# [Epoch 70] Train Loss: 1.3073 | Train Acc: 0.7470 | Train Perplexity: 3.6961
# [Validation] color: Loss=1.7881 | Acc=0.5814 | Perplexity=5.9779
# [Validation] shape: Loss=1.9179 | Acc=0.5355 | Perplexity=6.8066
# [Validation] quantity: Loss=2.3897 | Acc=0.3896 | Perplexity=10.9099
# [Validation Summary] Val Loss: 2.0319 | Val Acc: 0.5022 | Val Perplexity: 7.8982
#
# ----------------------------------------
#
# Epoch 71/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3011
# Train Batch 101/450 | Loss: 1.4357
# Train Batch 201/450 | Loss: 1.3096
# Train Batch 301/450 | Loss: 1.3721
# Train Batch 401/450 | Loss: 1.3717
# Train Batch 450/450 | Loss: 1.2353
# [Epoch 71] Train Loss: 1.3092 | Train Acc: 0.7452 | Train Perplexity: 3.7033
# [Validation] color: Loss=1.7798 | Acc=0.5949 | Perplexity=5.9285
# [Validation] shape: Loss=1.9450 | Acc=0.5421 | Perplexity=6.9937
# [Validation] quantity: Loss=2.4261 | Acc=0.3960 | Perplexity=11.3143
# [Validation Summary] Val Loss: 2.0503 | Val Acc: 0.5110 | Val Perplexity: 8.0788
#
# ----------------------------------------
#
# Epoch 72/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3130
# Train Batch 101/450 | Loss: 1.2318
# Train Batch 201/450 | Loss: 1.2405
# Train Batch 301/450 | Loss: 1.2770
# Train Batch 401/450 | Loss: 1.2071
# Train Batch 450/450 | Loss: 1.3257
# [Epoch 72] Train Loss: 1.2923 | Train Acc: 0.7540 | Train Perplexity: 3.6412
# [Validation] color: Loss=1.7704 | Acc=0.5939 | Perplexity=5.8735
# [Validation] shape: Loss=1.9252 | Acc=0.5334 | Perplexity=6.8567
# [Validation] quantity: Loss=2.4313 | Acc=0.3837 | Perplexity=11.3735
# [Validation Summary] Val Loss: 2.0423 | Val Acc: 0.5037 | Val Perplexity: 8.0346
#
# ----------------------------------------
#
# Epoch 73/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.2094
# Train Batch 101/450 | Loss: 1.3007
# Train Batch 201/450 | Loss: 1.2159
# Train Batch 301/450 | Loss: 1.2486
# Train Batch 401/450 | Loss: 1.3391
# Train Batch 450/450 | Loss: 1.2422
# [Epoch 73] Train Loss: 1.2901 | Train Acc: 0.7525 | Train Perplexity: 3.6332
# ...
#
# ----------------------------------------
#
# Epoch 77/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5069
# Train Batch 101/450 | Loss: 1.4798
# Train Batch 201/450 | Loss: 1.5364
# Train Batch 301/450 | Loss: 1.5552
# Train Batch 401/450 | Loss: 1.5098
# Train Batch 450/450 | Loss: 1.5467
# [Epoch 77] Train Loss: 1.4621 | Train Acc: 0.6703 | Train Perplexity: 4.3151
# [Validation] color: Loss=1.5097 | Acc=0.6676 | Perplexity=4.5252
# [Validation] shape: Loss=1.5794 | Acc=0.6243 | Perplexity=4.8518
# [Validation] quantity: Loss=1.9994 | Acc=0.4450 | Perplexity=7.3847
# [Validation Summary] Val Loss: 1.6961 | Val Acc: 0.5790 | Val Perplexity: 5.5872
#
# ----------------------------------------
#
# Epoch 78/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.4242
# Train Batch 101/450 | Loss: 1.3681
# Train Batch 201/450 | Loss: 1.3882
# Train Batch 301/450 | Loss: 1.4512
# Train Batch 401/450 | Loss: 1.3755
# Train Batch 450/450 | Loss: 1.4991
# [Epoch 78] Train Loss: 1.4512 | Train Acc: 0.6755 | Train Perplexity: 4.2681
# [Validation] color: Loss=1.5036 | Acc=0.6745 | Perplexity=4.4977
# [Validation] shape: Loss=1.5880 | Acc=0.6241 | Perplexity=4.8938
# [Validation] quantity: Loss=2.0243 | Acc=0.4428 | Perplexity=7.5711
# [Validation Summary] Val Loss: 1.7053 | Val Acc: 0.5805 | Val Perplexity: 5.6542
#
# ----------------------------------------
#
# Epoch 79/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.4240
# Train Batch 101/450 | Loss: 1.4543
# Train Batch 201/450 | Loss: 1.3275
# Train Batch 301/450 | Loss: 1.3727
# Train Batch 401/450 | Loss: 1.4518
# Train Batch 450/450 | Loss: 1.4372
# [Epoch 79] Train Loss: 1.4415 | Train Acc: 0.6817 | Train Perplexity: 4.2268
# [Validation] color: Loss=1.5215 | Acc=0.6710 | Perplexity=4.5792
# [Validation] shape: Loss=1.5663 | Acc=0.6418 | Perplexity=4.7889
# [Validation] quantity: Loss=2.0360 | Acc=0.4455 | Perplexity=7.6601
# [Validation Summary] Val Loss: 1.7079 | Val Acc: 0.5861 | Val Perplexity: 5.6761
#
# ----------------------------------------
#
# Epoch 80/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.5440
# Train Batch 101/450 | Loss: 1.3881
# Train Batch 201/450 | Loss: 1.3171
# Train Batch 301/450 | Loss: 1.4057
# Train Batch 401/450 | Loss: 1.2946
# Train Batch 450/450 | Loss: 1.4480
# [Epoch 80] Train Loss: 1.4435 | Train Acc: 0.6808 | Train Perplexity: 4.2354
# [Validation] color: Loss=1.5153 | Acc=0.6685 | Perplexity=4.5509
# [Validation] shape: Loss=1.6052 | Acc=0.6224 | Perplexity=4.9790
# [Validation] quantity: Loss=2.0620 | Acc=0.4470 | Perplexity=7.8616
# [Validation Summary] Val Loss: 1.7275 | Val Acc: 0.5793 | Val Perplexity: 5.7972
#
# ----------------------------------------
#
# Epoch 81/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3391
# Train Batch 101/450 | Loss: 1.3901
# Train Batch 201/450 | Loss: 1.5204
# Train Batch 301/450 | Loss: 1.2766
# Train Batch 401/450 | Loss: 1.2619
# Train Batch 450/450 | Loss: 1.5196
# [Epoch 81] Train Loss: 1.4293 | Train Acc: 0.6855 | Train Perplexity: 4.1757
# [Validation] color: Loss=1.4793 | Acc=0.6867 | Perplexity=4.3898
# [Validation] shape: Loss=1.6183 | Acc=0.6177 | Perplexity=5.0443
# [Validation] quantity: Loss=2.0483 | Acc=0.4456 | Perplexity=7.7549
# [Validation Summary] Val Loss: 1.7153 | Val Acc: 0.5833 | Val Perplexity: 5.7297
#
# ----------------------------------------
#
# Epoch 82/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3799
# Train Batch 101/450 | Loss: 1.3954
# Train Batch 201/450 | Loss: 1.4692
# Train Batch 301/450 | Loss: 1.2664
# Train Batch 401/450 | Loss: 1.3513
# Train Batch 450/450 | Loss: 1.4658
# [Epoch 82] Train Loss: 1.4257 | Train Acc: 0.6867 | Train Perplexity: 4.1608
# [Validation] color: Loss=1.5137 | Acc=0.6754 | Perplexity=4.5434
# [Validation] shape: Loss=1.6229 | Acc=0.6157 | Perplexity=5.0677
# [Validation] quantity: Loss=2.0753 | Acc=0.4461 | Perplexity=7.9667
# [Validation Summary] Val Loss: 1.7373 | Val Acc: 0.5791 | Val Perplexity: 5.8593
#
# ----------------------------------------
#
# Epoch 83/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3945
# Train Batch 101/450 | Loss: 1.4845
# Train Batch 201/450 | Loss: 1.4239
# Train Batch 301/450 | Loss: 1.3758
# Train Batch 401/450 | Loss: 1.4775
# Train Batch 450/450 | Loss: 1.4617
# [Epoch 83] Train Loss: 1.4235 | Train Acc: 0.6912 | Train Perplexity: 4.1518
# [Validation] color: Loss=1.5064 | Acc=0.6775 | Perplexity=4.5103
# [Validation] shape: Loss=1.5953 | Acc=0.6260 | Perplexity=4.9297
# [Validation] quantity: Loss=2.0213 | Acc=0.4482 | Perplexity=7.5480
# [Validation Summary] Val Loss: 1.7076 | Val Acc: 0.5839 | Val Perplexity: 5.6627
#
# ----------------------------------------
#
# Epoch 84/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3589
# Train Batch 101/450 | Loss: 1.3149
# Train Batch 201/450 | Loss: 1.3684
# Train Batch 301/450 | Loss: 1.4913
# Train Batch 401/450 | Loss: 1.5427
# Train Batch 450/450 | Loss: 1.4227
# [Epoch 84] Train Loss: 1.4124 | Train Acc: 0.6932 | Train Perplexity: 4.1057
# [Validation] color: Loss=1.5210 | Acc=0.6666 | Perplexity=4.5770
# [Validation] shape: Loss=1.6100 | Acc=0.6217 | Perplexity=5.0026
# [Validation] quantity: Loss=2.0557 | Acc=0.4425 | Perplexity=7.8121
# [Validation Summary] Val Loss: 1.7289 | Val Acc: 0.5769 | Val Perplexity: 5.7973
#
# ----------------------------------------
#
# Epoch 85/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3655
# Train Batch 101/450 | Loss: 1.3490
# Train Batch 201/450 | Loss: 1.4749
# Train Batch 301/450 | Loss: 1.2516
# Train Batch 401/450 | Loss: 1.4715
# Train Batch 450/450 | Loss: 1.4648
# [Epoch 85] Train Loss: 1.4003 | Train Acc: 0.7004 | Train Perplexity: 4.0563
# [Validation] color: Loss=1.5435 | Acc=0.6627 | Perplexity=4.6810
# [Validation] shape: Loss=1.5972 | Acc=0.6303 | Perplexity=4.9394
# [Validation] quantity: Loss=2.0709 | Acc=0.4499 | Perplexity=7.9318
# [Validation Summary] Val Loss: 1.7372 | Val Acc: 0.5810 | Val Perplexity: 5.8507
#
# ----------------------------------------
#
# Epoch 86/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.4130
# Train Batch 101/450 | Loss: 1.4678
# Train Batch 201/450 | Loss: 1.5503
# Train Batch 301/450 | Loss: 1.4371
# Train Batch 401/450 | Loss: 1.3478
# Train Batch 450/450 | Loss: 1.3444
# [Epoch 86] Train Loss: 1.3975 | Train Acc: 0.7035 | Train Perplexity: 4.0451
# [Validation] color: Loss=1.5543 | Acc=0.6534 | Perplexity=4.7318
# [Validation] shape: Loss=1.5977 | Acc=0.6270 | Perplexity=4.9415
# [Validation] quantity: Loss=2.0685 | Acc=0.4478 | Perplexity=7.9126
# [Validation Summary] Val Loss: 1.7401 | Val Acc: 0.5761 | Val Perplexity: 5.8620
#
# ----------------------------------------
#
# Epoch 87/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3550
# Train Batch 101/450 | Loss: 1.2384
# Train Batch 201/450 | Loss: 1.4188
# Train Batch 301/450 | Loss: 1.4459
# Train Batch 401/450 | Loss: 1.3806
# Train Batch 450/450 | Loss: 1.4469
# [Epoch 87] Train Loss: 1.3905 | Train Acc: 0.7056 | Train Perplexity: 4.0167
# [Validation] color: Loss=1.5439 | Acc=0.6544 | Perplexity=4.6826
# [Validation] shape: Loss=1.5835 | Acc=0.6284 | Perplexity=4.8719
# [Validation] quantity: Loss=2.0600 | Acc=0.4499 | Perplexity=7.8457
# [Validation Summary] Val Loss: 1.7291 | Val Acc: 0.5776 | Val Perplexity: 5.8001
#
# ----------------------------------------
#
# Epoch 88/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3176
# Train Batch 101/450 | Loss: 1.3209
# Train Batch 201/450 | Loss: 1.4991
# Train Batch 301/450 | Loss: 1.2660
# Train Batch 401/450 | Loss: 1.4382
# Train Batch 450/450 | Loss: 1.3070
# [Epoch 88] Train Loss: 1.3844 | Train Acc: 0.7078 | Train Perplexity: 3.9923
# [Validation] color: Loss=1.5361 | Acc=0.6577 | Perplexity=4.6462
# [Validation] shape: Loss=1.5789 | Acc=0.6272 | Perplexity=4.8497
# [Validation] quantity: Loss=2.0174 | Acc=0.4585 | Perplexity=7.5188
# [Validation Summary] Val Loss: 1.7108 | Val Acc: 0.5811 | Val Perplexity: 5.6716
#
# ----------------------------------------
#
# Epoch 89/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3723
# Train Batch 101/450 | Loss: 1.2381
# Train Batch 201/450 | Loss: 1.5517
# Train Batch 301/450 | Loss: 1.3073
# Train Batch 401/450 | Loss: 1.4260
# Train Batch 450/450 | Loss: 1.4953
# [Epoch 89] Train Loss: 1.3811 | Train Acc: 0.7083 | Train Perplexity: 3.9792
# [Validation] color: Loss=1.5046 | Acc=0.6754 | Perplexity=4.5023
# [Validation] shape: Loss=1.6406 | Acc=0.6128 | Perplexity=5.1584
# [Validation] quantity: Loss=2.0459 | Acc=0.4573 | Perplexity=7.7357
# [Validation Summary] Val Loss: 1.7304 | Val Acc: 0.5818 | Val Perplexity: 5.7988
#
# ----------------------------------------
#
# Epoch 90/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3342
# Train Batch 101/450 | Loss: 1.4442
# Train Batch 201/450 | Loss: 1.4156
# Train Batch 301/450 | Loss: 1.3930
# Train Batch 401/450 | Loss: 1.3069
# Train Batch 450/450 | Loss: 1.3920
# [Epoch 90] Train Loss: 1.3728 | Train Acc: 0.7145 | Train Perplexity: 3.9462
# [Validation] color: Loss=1.5532 | Acc=0.6514 | Perplexity=4.7266
# [Validation] shape: Loss=1.6404 | Acc=0.6064 | Perplexity=5.1575
# [Validation] quantity: Loss=2.1002 | Acc=0.4455 | Perplexity=8.1682
# [Validation Summary] Val Loss: 1.7646 | Val Acc: 0.5677 | Val Perplexity: 6.0174
#
# ----------------------------------------
#
# Epoch 91/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3861
# Train Batch 101/450 | Loss: 1.2713
# Train Batch 201/450 | Loss: 1.2154
# Train Batch 301/450 | Loss: 1.3067
# Train Batch 401/450 | Loss: 1.4409
# Train Batch 450/450 | Loss: 1.3861
# [Epoch 91] Train Loss: 1.3655 | Train Acc: 0.7156 | Train Perplexity: 3.9177
# [Validation] color: Loss=1.5164 | Acc=0.6709 | Perplexity=4.5560
# [Validation] shape: Loss=1.6239 | Acc=0.6191 | Perplexity=5.0726
# [Validation] quantity: Loss=2.1028 | Acc=0.4533 | Perplexity=8.1890
# [Validation Summary] Val Loss: 1.7477 | Val Acc: 0.5811 | Val Perplexity: 5.9392
#
# ----------------------------------------
#
# Epoch 92/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3630
# Train Batch 101/450 | Loss: 1.2855
# Train Batch 201/450 | Loss: 1.5387
# Train Batch 301/450 | Loss: 1.3052
# Train Batch 401/450 | Loss: 1.2133
# Train Batch 450/450 | Loss: 1.2670
# [Epoch 92] Train Loss: 1.3546 | Train Acc: 0.7214 | Train Perplexity: 3.8753
# [Validation] color: Loss=1.5237 | Acc=0.6668 | Perplexity=4.5890
# [Validation] shape: Loss=1.6385 | Acc=0.6133 | Perplexity=5.1475
# [Validation] quantity: Loss=2.1082 | Acc=0.4520 | Perplexity=8.2336
# [Validation Summary] Val Loss: 1.7568 | Val Acc: 0.5774 | Val Perplexity: 5.9900
#
# ----------------------------------------
#
# Epoch 93/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3103
# Train Batch 101/450 | Loss: 1.3348
# Train Batch 201/450 | Loss: 1.2510
# Train Batch 301/450 | Loss: 1.1964
# Train Batch 401/450 | Loss: 1.2883
# Train Batch 450/450 | Loss: 1.4719
# [Epoch 93] Train Loss: 1.3503 | Train Acc: 0.7243 | Train Perplexity: 3.8586
# [Validation] color: Loss=1.5295 | Acc=0.6622 | Perplexity=4.6160
# [Validation] shape: Loss=1.5838 | Acc=0.6301 | Perplexity=4.8733
# [Validation] quantity: Loss=2.0407 | Acc=0.4531 | Perplexity=7.6963
# [Validation Summary] Val Loss: 1.7180 | Val Acc: 0.5818 | Val Perplexity: 5.7286
#
# ----------------------------------------
#
# Epoch 94/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3854
# Train Batch 101/450 | Loss: 1.3656
# Train Batch 201/450 | Loss: 1.2227
# Train Batch 301/450 | Loss: 1.3052
# Train Batch 401/450 | Loss: 1.2835
# Train Batch 450/450 | Loss: 1.3316
# [Epoch 94] Train Loss: 1.3422 | Train Acc: 0.7278 | Train Perplexity: 3.8274
# [Validation] color: Loss=1.5410 | Acc=0.6671 | Perplexity=4.6694
# [Validation] shape: Loss=1.6438 | Acc=0.6166 | Perplexity=5.1748
# [Validation] quantity: Loss=2.1333 | Acc=0.4509 | Perplexity=8.4427
# [Validation Summary] Val Loss: 1.7727 | Val Acc: 0.5782 | Val Perplexity: 6.0957
#
# ----------------------------------------
#
# Epoch 95/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3056
# Train Batch 101/450 | Loss: 1.3491
# Train Batch 201/450 | Loss: 1.1778
# Train Batch 301/450 | Loss: 1.2861
# Train Batch 401/450 | Loss: 1.3777
# Train Batch 450/450 | Loss: 1.4405
# [Epoch 95] Train Loss: 1.3373 | Train Acc: 0.7328 | Train Perplexity: 3.8089
# [Validation] color: Loss=1.5691 | Acc=0.6461 | Perplexity=4.8025
# [Validation] shape: Loss=1.6169 | Acc=0.6184 | Perplexity=5.0376
# [Validation] quantity: Loss=2.1047 | Acc=0.4486 | Perplexity=8.2049
# [Validation Summary] Val Loss: 1.7636 | Val Acc: 0.5711 | Val Perplexity: 6.0150
#
# ----------------------------------------
#
# Epoch 96/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3295
# Train Batch 101/450 | Loss: 1.3368
# Train Batch 201/450 | Loss: 1.4973
# Train Batch 301/450 | Loss: 1.4061
# Train Batch 401/450 | Loss: 1.2347
# Train Batch 450/450 | Loss: 1.2543
# [Epoch 96] Train Loss: 1.3332 | Train Acc: 0.7303 | Train Perplexity: 3.7930
# [Validation] color: Loss=1.5410 | Acc=0.6613 | Perplexity=4.6693
# [Validation] shape: Loss=1.6205 | Acc=0.6193 | Perplexity=5.0554
# [Validation] quantity: Loss=2.1175 | Acc=0.4431 | Perplexity=8.3103
# [Validation Summary] Val Loss: 1.7597 | Val Acc: 0.5745 | Val Perplexity: 6.0117
#
# ----------------------------------------
#
# Epoch 97/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3809
# Train Batch 101/450 | Loss: 1.2098
# Train Batch 201/450 | Loss: 1.3298
# Train Batch 301/450 | Loss: 1.1767
# Train Batch 401/450 | Loss: 1.3444
# Train Batch 450/450 | Loss: 1.2420
# [Epoch 97] Train Loss: 1.3215 | Train Acc: 0.7361 | Train Perplexity: 3.7491
# [Validation] color: Loss=1.5464 | Acc=0.6590 | Perplexity=4.6946
# [Validation] shape: Loss=1.6309 | Acc=0.6200 | Perplexity=5.1084
# [Validation] quantity: Loss=2.1477 | Acc=0.4407 | Perplexity=8.5653
# [Validation Summary] Val Loss: 1.7750 | Val Acc: 0.5732 | Val Perplexity: 6.1228
#
# ----------------------------------------
#
# Epoch 98/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.3510
# Train Batch 101/450 | Loss: 1.4456
# Train Batch 201/450 | Loss: 1.2072
# Train Batch 301/450 | Loss: 1.3812
# Train Batch 401/450 | Loss: 1.3531
# Train Batch 450/450 | Loss: 1.3310
# [Epoch 98] Train Loss: 1.3126 | Train Acc: 0.7417 | Train Perplexity: 3.7159
# [Validation] color: Loss=1.5437 | Acc=0.6680 | Perplexity=4.6818
# [Validation] shape: Loss=1.6275 | Acc=0.6266 | Perplexity=5.0912
# [Validation] quantity: Loss=2.2114 | Acc=0.4452 | Perplexity=9.1287
# [Validation Summary] Val Loss: 1.7942 | Val Acc: 0.5799 | Val Perplexity: 6.3006
#
# ----------------------------------------
#
# Epoch 99/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.2629
# Train Batch 101/450 | Loss: 1.2455
# Train Batch 201/450 | Loss: 1.2960
# Train Batch 301/450 | Loss: 1.2120
# Train Batch 401/450 | Loss: 1.2375
# Train Batch 450/450 | Loss: 1.3292
# [Epoch 99] Train Loss: 1.3017 | Train Acc: 0.7469 | Train Perplexity: 3.6755
# [Validation] color: Loss=1.5835 | Acc=0.6451 | Perplexity=4.8720
# [Validation] shape: Loss=1.6020 | Acc=0.6240 | Perplexity=4.9631
# [Validation] quantity: Loss=2.1160 | Acc=0.4430 | Perplexity=8.2975
# [Validation Summary] Val Loss: 1.7672 | Val Acc: 0.5707 | Val Perplexity: 6.0442
#
# ----------------------------------------
#
# Epoch 100/100
# ----------------------------------------
# Train Batch 1/450 | Loss: 1.2188
# Train Batch 101/450 | Loss: 1.3459
# Train Batch 201/450 | Loss: 1.2617
# Train Batch 301/450 | Loss: 1.3460
# Train Batch 401/450 | Loss: 1.4103
# Train Batch 450/450 | Loss: 1.2066
# [Epoch 100] Train Loss: 1.3004 | Train Acc: 0.7498 | Train Perplexity: 3.6707
# [Validation] color: Loss=1.5582 | Acc=0.6655 | Perplexity=4.7502
# [Validation] shape: Loss=1.6541 | Acc=0.6229 | Perplexity=5.2285
# [Validation] quantity: Loss=2.1987 | Acc=0.4535 | Perplexity=9.0130
# [Validation Summary] Val Loss: 1.8037 | Val Acc: 0.5807 | Val Perplexity: 6.3306
#
# ----------------------------------------
#
# Training complete
# [Test] Loss: 1.7128 | Acc: 0.6102 | Perplexity: 5.5444

# %% [markdown]
# ### 3. Save Training & Test Results

# %%
import json

# %%
for i, result in enumerate(results):
    with open(f"./../results/baseline_transformer_performace_seed-{SEEDS[i]}.json", "w") as file:
        json.dump(result, file, indent=4)
